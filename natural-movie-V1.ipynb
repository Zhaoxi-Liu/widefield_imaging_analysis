# %%
import NeuroAnalysisTools
import NeuroAnalysisTools.core.FileTools as ft
import NeuroAnalysisTools.RetinotopicMapping as rm
import pickle
import numpy as np
import pandas as pd
import os
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import cv2
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from scipy.ndimage import gaussian_filter, median_filter
import timeit
from glob import glob
from NatMovie_utils import *

# %%
path_wfield = '/home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie-reverse/process/20240708-210000-wfield'

experiment = os.path.basename(path_wfield)[:15]
rawPath = pjoin(path_wfield, '../../raw')
path_out = pjoin(path_wfield, '..', experiment + '-natural-movie')
os.makedirs(path_out, exist_ok=True)
trialfile = pd.read_csv(pjoin(path_wfield, 'trials.csv'), header=None).values.astype(int)
movie_folder = pjoin(rawPath, 'natural_movies')
movie_list = pd.read_csv(pjoin(movie_folder, 'movie_list.txt'), header=None).values
n_movie = movie_list.size
movie_name_list = []
for imovie in range(n_movie):
    movie_name_list.append(str(movie_list[imovie])[2:-6])

n_frame = 150  # 帧

# %%
path_retinotopy = r'/home/lzx/data/WF_VC_liuzhaoxi/P73/20240718/retinotopy/process/20240718-161348-retinotopy'

with open(pjoin(path_retinotopy, 'retinotopy_out.pkl'), 'rb') as f:
    retino = pickle.load(f)
f.close()
n_patch = len(retino['finalPatchesMarked'])

# %%
U = np.load(pjoin(path_wfield, 'U.npy')).astype('float32')
SVTcorr = np.load(pjoin(path_wfield, 'SVTcorr.npy')).astype('float32')
frames_average = np.load(pjoin(path_wfield, 'frames_average.npy')).astype('float32')[0]

# %%
pre_lenth = 20
after_lenth = 30
# SVTcorr_sort维度：[nSVD, n_frame, n_movie, n_rep]
SVTcorr_sort = sorting_NatMov(SVTcorr, trialfile[:, 1], n_movie, n_frame, pre_lenth, after_lenth).astype('float32')
print('SVTcorr_sort.shape: (nSVD, n_frame, n_movie, n_rep) ', SVTcorr_sort.shape)
n_rep = SVTcorr_sort.shape[-1]
SVTcorr_mean = np.mean(SVTcorr_sort, axis=3)
# Out:
# SVTcorr_sort.shape: (nSVD, n_frame, n_movie, n_rep)  (200, 200, 14, 5)

# %%
path_out_tif = pjoin(path_out, experiment + '-tif-rep-reshape')
os.makedirs(path_out_tif, exist_ok=True)
snr = np.empty((U.shape[0], U.shape[1], n_movie))

for imovie in range(n_movie):
    print('start processing {}-{}'.format(imovie + 1, movie_name_list[imovie]))
    tif_imovie = np.tensordot(U, SVTcorr_sort[:, :, imovie, :], axes=(2, 0)).astype('float32')
    snr[:, :, imovie] = cal_snr(tif_imovie, axis1=3, axis2=2)
    tif_imovie_mean = np.mean(tif_imovie, axis=3)
    tif_imovie_with_mean = np.concatenate((tif_imovie_mean[..., np.newaxis], tif_imovie), axis=3)
    tif_rep_reshape = np.concatenate(np.split(tif_imovie_with_mean, tif_imovie_with_mean.shape[3], axis=3),
                             axis=1).squeeze().transpose(2, 0, 1)
    # tif_imovie_mean = tif_imovie_mean.transpose(2, 0, 1)
    imwrite(pjoin(path_out_tif, movie_name_list[imovie] + '-rep-reshape.tif'), tif_rep_reshape, imagej=True)
print('export all rep_reshape-tifs')
np.save(pjoin(path_out, 'snr.npy'), snr)
# Out:
# start processing 1-forest
# start processing 2-Heron
# start processing 3-crow_peck_mouse1
# start processing 4-owl_peck
# start processing 5-cat
# start processing 6-cat_catch_mouse1
# start processing 7-cat_eat_mouse
# start processing 8-cat_pat
# start processing 9-run_to_cat
# start processing 10-bugs
# start processing 11-mouse_catch_bug
# start processing 12-mouse_fight
# start processing 13-mouse_birth
# start processing 14-lawn_and_dog
# export all rep_reshape-tifs

# %%
path_out_rep_tif = pjoin(path_out, experiment + '-tif-rep')
os.makedirs(path_out_rep_tif, exist_ok=True)

tif_sort = np.tensordot(U, SVTcorr_sort, axes=(2, 0)).astype('float32')
# tif_sort维度：[width, height, n_frame, n_movie, n_rep]
tif_mean = np.mean(tif_sort, axis=-1)
tif_with_mean = np.concatenate((tif_mean[..., np.newaxis], tif_sort), axis=-1)
tif_rep_reshape = np.concatenate(np.split(tif_with_mean, tif_with_mean.shape[-1], axis=-1),
                                 axis=1).squeeze().transpose(2, 0, 1, 3)
for imovie in range(n_movie):
    print('start processing {}-{}'.format(imovie + 1, movie_name_list[imovie]))
    imwrite(pjoin(path_out_rep_tif, movie_name_list[imovie] + '-rep-reshape.tif'), tif_rep_reshape[:, :, :, imovie].astype('float32'),
            imagej=True)
print('export all rep-reshape-tifs')

tif_rep = np.concatenate(np.split(tif_sort, tif_sort.shape[-1], axis=-1),
                         axis=2).squeeze().transpose(2, 0, 1, 3)
for imovie in range(n_movie):
    print('start processing {}-{}'.format(imovie + 1, movie_name_list[imovie]))
    imwrite(pjoin(path_out_rep_tif, movie_name_list[imovie] + '-rep.tif'),
            tif_rep[:, :, :, imovie].astype('float32'), imagej=True)
print('export all rep-tifs')

# %%
from wfield import *

lmarks = load_allen_landmarks(pjoin(path_wfield, 'dorsal_cortex_landmarks.json'))
ccf_regions_reference, proj, brain_outline = allen_load_reference('dorsal_cortex')
# this loads the untransformed atlas
atlas_im, areanames, brain_mask = atlas_from_landmarks_file(pjoin(path_wfield, 'dorsal_cortex_landmarks.json'),
                                                            do_transform=True)
# this converts the reference to image space (unwarped)
ccf_regions_im = allen_transform_regions(lmarks['transform'], ccf_regions_reference,
                                         resolution=lmarks['resolution'],
                                         bregma_offset=lmarks['bregma_offset'])

# %%
merge_frame_size = (512, 512)  # (width, height)
fig = plt.figure(figsize=(merge_frame_size[0] / 128, merge_frame_size[1] / 128), dpi=128)
plt.imshow(frames_average, cmap='gray')
for i, r in ccf_regions_im.iterrows():
    plt.plot(r['left_x'], r['left_y'], 'r', lw=0.2)
    plt.plot(r['right_x'], r['right_y'], 'r', lw=0.2)
    plt.text(r.left_center[0], r.left_center[1], r.acronym, color='w', va='center', fontsize=3, alpha=1, ha='center')

plt.axis('off')
fig.set_facecolor('white')
plt.savefig(pjoin(path_out, 'ccf.png'), bbox_inches='tight', pad_inches=0)
plt.show()

# %%
snr = np.load(pjoin(path_out, 'snr.npy'))
subplot_movie_heatmap(snr, 4, 4, movie_name_list, path_outfile=pjoin(path_out, 'SNR_per_movie.png'),
                      title=experiment + '-snr', vmax=4, pixel_um=13, patches=None,
                      ccf_regions=ccf_regions_im)

# std = np.std(tif_sort, axis=(2, 4))
# np.save(pjoin(path_out, 'std.npy'), std)
# subplot_movie_heatmap(std, 4, 4, movie_list, path_outfile=pjoin(path_out, 'std_per_movie.png'), title=experiment+'-std', vmin=0.01, vmax=0.1,
#                       pixel_um=13, patches=None, ccf_regions=ccf_regions_im)

# %%
logSNR=np.log(snr+1)
subplot_movie_heatmap(logSNR, 4, 4, movie_name_list, path_outfile=pjoin(path_out, 'logSNR_per_movie.png'),
                      cmap='hot', title=experiment + '-log(snr)', pixel_um=13, patches=None,
                      ccf_regions=ccf_regions_im)

# %%
from pupil_utils import *

path_pupil = pjoin(path_out, experiment + '-pupil')
pupil_pkl_data = glob(pjoin(path_pupil, '*pupil_detection*.pkl'))[0]
with open(pupil_pkl_data, 'rb') as f:
    pupil_pkl = pickle.load(f)
f.close()

pupil_area_sort = sorting_NatMov_pupil(pupil_pkl['Pupil_area'], trialfile[:, 1], n_movie, n_frame)
# pupil_area_sort_nmovie = np.concatenate(np.split(pupil_area_sort, pupil_area_sort.shape[2], axis=2),
#                                         axis=0).squeeze().transpose(1, 0)
pupil_area_sort_nmovie = pupil_area_sort.transpose(1, 0, 2).reshape(n_movie, n_frame * n_rep)
# tif_nmovie = np.concatenate(np.split(tif_sort, tif_sort.shape[-1], axis=-1),
#                                         axis=-3).squeeze().transpose(0, 1, 3, 2)
tif_nmovie = tif_sort.transpose(0, 1, 3, 2, 4).reshape(*tif_sort.shape[0:2], n_movie, n_frame * n_rep)
pupil_cor = np.empty((tif_nmovie.shape[:3]))
def cal_corrcoef(A, B, rowvar=False):
    # 计算arr和B的相关系数
    return np.corrcoef(A, B, rowvar=rowvar)[0, 1]
for imovie in range(n_movie):
    pupil_cor[:, :, imovie] = np.apply_along_axis(cal_corrcoef, -1, tif_nmovie[:, :, imovie, :],
                                                  B=pupil_area_sort_nmovie[imovie, :])
np.save(pjoin(path_pupil, 'pupil_corrcoef.npy'), pupil_cor)
subplot_movie_heatmap(pupil_cor[:, :, :12], 4, 4, movie_list,
                      path_outfile=pjoin(path_out, 'pupil_corrcoef_per_movie.png'), title=experiment + '-corrcoef',
                      cmap='coolwarm', pixel_um=13, patches=None, ccf_regions=ccf_regions_im, ccf_color='k')

# 画瞳孔大小变化
fig, axes = plt.subplots(5, 14, figsize=(50, 6))
for i_rep in range(5):
    for i_movie in range(14):
        axes[i_rep, i_movie].plot(pupil_area_sort[:, i_movie, i_rep])
        axes[i_rep, i_movie].set_xlim(0, n_frame)
        axes[i_rep, i_movie].set_title(movie_name_list[i_movie], fontsize=5)
        axes[i_rep, i_movie].tick_params(labelsize=5)
plt.tight_layout()
fig.set_facecolor('white')
plt.savefig(pjoin(path_pupil, 'pupil_area_change.png'))
plt.show()

# %%
path_patch_stim = pjoin(path_out, experiment + '-patch-stim')
os.makedirs(path_patch_stim, exist_ok=True)
for imovie in range(n_movie):
    movie_name = movie_name_list[imovie]
    movie_file = pjoin(movie_folder, movie_name + '.mp4')
    tif_file = pjoin(path_out_tif, movie_name + '.tif')
    merge_file = pjoin(path_patch_stim, movie_name + '-patch-stim.mp4')
    merge_patch_stim(merge_file, tif_file, movie_file, clip=0.05, patches=retino['finalPatchesMarked'], ncol=1,
                     text='{}-{} '.format(imovie + 1, movie_name))
    print('finish merging {}-{}'.format(imovie + 1, movie_name))

print('finish all merging')

# %%
path_ccf = pjoin(path_out, experiment + '-ccf')
os.makedirs(path_ccf, exist_ok=True)

for imovie in range(n_movie):
    # reconstruct the mean movie
    SVT_mean_imovie = SVTcorr_mean[:, :, imovie]
    stack = SVDStack(U, SVT_mean_imovie)
    stack.set_warped(False, M=lmarks['transform'])

    mp4_outfile = pjoin(path_ccf, movie_name_list[imovie] + '-ccf.mp4')
    out = cv2.VideoWriter(mp4_outfile, cv2.VideoWriter_fourcc(*'mp4v'), 10, merge_frame_size)
    if not out.isOpened():
        print("视频文件无法打开：", mp4_outfile)
        continue

    for iframe in range(n_frame):
        # plot iframe with allen map
        fig = plt.figure(figsize=(merge_frame_size[0] / 128, merge_frame_size[1] / 128), dpi=128)
        plt.gca().xaxis.set_major_locator(plt.NullLocator())
        plt.gca().yaxis.set_major_locator(plt.NullLocator())
        plt.subplots_adjust(top=1, bottom=0, right=1, left=0, hspace=0, wspace=0)
        plt.margins(0, 0)
        plt.imshow(reconstruct(stack.originalU, stack.SVT[:, iframe]), clim=[-0.05, 0.05], cmap='gray')
        for i, r in ccf_regions_im.iterrows():
            plt.plot(r['left_x'], r['left_y'], 'r', lw=0.2)
            plt.plot(r['right_x'], r['right_y'], 'r', lw=0.2)
            plt.text(r.left_center[0], r.left_center[1], r.acronym, color='w', va='center', fontsize=6, alpha=0.5,
                     ha='center')
        plt.axis('off')
        fig.set_facecolor('white')
        # export to mp4 video
        # plt.savefig(pjoin(mp4_outfile, 'tmp.png'), bbox_inches='tight', pad_inches=0)
        # frame_bgr = cv2.imread('tmp/frame{}.png'.format(iframe + 1))
        fig.canvas.draw()
        frame_argb = np.frombuffer(fig.canvas.tostring_argb(), dtype=np.uint8)
        frame_rgba = np.roll(frame_argb.reshape(fig.canvas.get_width_height()[::-1] + (4,)), 3, axis=2)
        frame_bgr = cv2.cvtColor(frame_rgba, cv2.COLOR_RGBA2BGR)
        plt.close(fig)

        if frame_bgr is None:
            print('帧数据为空：第 {} 帧'.format(iframe + 1))
            print('error when merging {}.mp4'.format(movie_name_list[imovie]))
            break

        if frame_bgr.shape[1] != merge_frame_size[0] or frame_bgr.shape[0] != merge_frame_size[1]:
            print('帧大小不匹配：第 {} 帧，大小 {}'.format(iframe + 1, frame_bgr.shape))
            # 调整帧大小
            frame_bgr = cv2.resize(frame_bgr, merge_frame_size, interpolation=cv2.INTER_LINEAR)

        # 写入帧到视频
        out.write(frame_bgr)
        print('finish merging {} {}th frame'.format(movie_name_list[imovie], iframe + 1))

    out.release()
    print('finish merging all frames of {}.mp4'.format(movie_name_list[imovie]))

# merge tif & ccf & stim
path_ccf = pjoin(path_out, experiment + '-ccf')
path_ccf_stim = pjoin(path_out, experiment + '-ccf-stim')
os.makedirs(path_ccf_stim, exist_ok=True)

for imovie in range(n_movie):
    movie_name = movie_name_list[imovie]
    movie_file = pjoin(movie_folder, movie_name + '.mp4')
    tif_file = pjoin(path_ccf, movie_name + '-ccf.mp4')
    merge_file = pjoin(path_ccf_stim, movie_name + '-ccf-stim.mp4')
    merge2video(merge_file, tif_file, movie_file, text='{}-{} '.format(imovie + 1, movie_name))
    print('finish merging {}-{}'.format(imovie + 1, movie_name))

print('finish all merging')

# %%
path_enhance_ccf_stim = pjoin(path_out, experiment + '-enhance-ccf-stim')
os.makedirs(path_enhance_ccf_stim, exist_ok=True)
for imovie in range(n_movie):
    movie_name = movie_name_list[imovie]
    movie_file = pjoin(movie_folder, movie_name + '.mp4')
    tif_file = pjoin(path_out, experiment + '-tif-enhance', movie_name + '_enhance.tif')
    merge_file = pjoin(path_enhance_ccf_stim, movie_name + '-ccf-stim.mp4')
    merge_ccf_stim(merge_file, tif_file, ccf_regions_im, stim_file=movie_file, tif_fps=10, vmin=200, vmax=25000,
                   trial_rep=1, text='{}-{} '.format(imovie + 1, movie_name))
    print('finish merging {}-{}'.format(imovie + 1, movie_name))
print('finish all merging')

path_rep_reshape_ccf_stim = pjoin(path_out, experiment + '-rep-reshape-ccf-stim')
os.makedirs(path_rep_reshape_ccf_stim, exist_ok=True)
for imovie in range(n_movie):
    movie_name = movie_name_list[imovie]
    movie_file = pjoin(movie_folder, movie_name + '.mp4')
    tif_file = pjoin(path_out, experiment + '-tif-rep-reshape', movie_name + '-rep-reshape.tif')
    merge_file = pjoin(path_rep_reshape_ccf_stim, movie_name + '-rep-reshape-ccf-stim.mp4')
    merge_ccf_stim(merge_file, tif_file, ccf_regions_im, stim_file=movie_file, ncol=6, nrow=1, vmin=-0.1, vmax=0.1,
                   trial_rep=1, text='{}-{} '.format(imovie + 1, movie_name))
    print('finish merging {}-{}'.format(imovie + 1, movie_name))
print('finish all merging')

path_rep_reshape_enhance_ccf_stim = pjoin(path_out, experiment + '-rep-reshape-enhance-ccf-stim')
os.makedirs(path_rep_reshape_enhance_ccf_stim, exist_ok=True)
for imovie in range(n_movie):
    movie_name = movie_name_list[imovie]
    movie_file = pjoin(movie_folder, movie_name + '.mp4')
    tif_file = pjoin(path_out, experiment + '-tif-rep-reshape-enhance', movie_name + '-rep-reshape-enhance.tif')
    merge_file = pjoin(path_rep_reshape_enhance_ccf_stim, movie_name + '-rep-reshape-enhance-ccf-stim.mp4')
    merge_ccf_stim(merge_file, tif_file, ccf_regions_im, stim_file=movie_file, ncol=5, nrow=1, vmin=200, vmax=25000,
                   trial_rep=1, text='{}-{} '.format(imovie + 1, movie_name))
    print('finish merging {}-{}'.format(imovie + 1, movie_name))
print('finish all merging')

path_rep_enhance_ccf_stim = pjoin(path_out, experiment + '-rep-enhance-ccf-stim')
os.makedirs(path_rep_enhance_ccf_stim, exist_ok=True)
for imovie in range(n_movie):
    movie_name = movie_name_list[imovie]
    movie_file = pjoin(movie_folder, movie_name + '.mp4')
    tif_file = pjoin(path_out, experiment + '-tif-rep-enhance', movie_name + '-rep-enhance.tif')
    merge_file = pjoin(path_rep_enhance_ccf_stim, movie_name + '-rep-enhance-ccf-stim.mp4')
    merge_ccf_stim(merge_file, tif_file, ccf_regions_im, stim_file=movie_file, tif_fps=10, vmin=200, vmax=25000,
                   trial_rep=10, text='{}-{} '.format(imovie + 1, movie_name))
    print('finish merging {}-{}'.format(imovie + 1, movie_name))
print('finish all merging')

path_rep_ccf_stim = pjoin(path_out, experiment + '-rep-ccf-stim')
os.makedirs(path_rep_ccf_stim, exist_ok=True)
for imovie in range(n_movie):
    movie_name = movie_name_list[imovie]
    movie_file = pjoin(movie_folder, movie_name + '.mp4')
    tif_file = pjoin(path_out, experiment + '-tif-rep', movie_name + '-rep.tif')
    merge_file = pjoin(path_rep_ccf_stim, movie_name + '-rep-ccf-stim.mp4')
    merge_ccf_stim(merge_file, tif_file, ccf_regions_im, stim_file=movie_file, tif_fps=10, vmin=-0.1, vmax=0.1,
                   trial_rep=10, text='{}-{} '.format(imovie + 1, movie_name))
    print('finish merging {}-{}'.format(imovie + 1, movie_name))
print('finish all merging')

# %%
path_rep_reshape_ccf_stim = pjoin(path_out, experiment + '-rep-reshape-ccf-stim')
os.makedirs(path_rep_reshape_ccf_stim, exist_ok=True)
for imovie in range(n_movie):
    movie_name = movie_name_list[imovie]
    movie_file = pjoin(movie_folder, movie_name + '.mp4')
    tif_file = pjoin(path_out, experiment + '-tif-rep-reshape', movie_name + '-rep-reshape.tif')
    merge_file = pjoin(path_rep_reshape_ccf_stim, movie_name + '-rep-reshape-ccf-stim.mp4')
    merge_ccf_stim(merge_file, tif_file, ccf_regions_im, stim_file=movie_file, ncol=6, nrow=1, vmin=-0.1, vmax=0.1,
                   trial_rep=1, text='{}-{} '.format(imovie + 1, movie_name), reverse=False)
    print('finish merging {}-{}'.format(imovie + 1, movie_name))
print('finish all merging')
# Out:
# finish merging 1-forest 1th frame
# finish merging 1-forest 2th frame
# finish merging 1-forest 3th frame
# finish merging 1-forest 4th frame
# finish merging 1-forest 5th frame
# finish merging 1-forest 6th frame
# finish merging 1-forest 7th frame
# finish merging 1-forest 8th frame
# finish merging 1-forest 9th frame
# finish merging 1-forest 10th frame
# finish merging 1-forest 11th frame
# finish merging 1-forest 12th frame
# finish merging 1-forest 13th frame
# finish merging 1-forest 14th frame
# finish merging 1-forest 15th frame
# finish merging 1-forest 16th frame
# finish merging 1-forest 17th frame
# finish merging 1-forest 18th frame
# finish merging 1-forest 19th frame
# finish merging 1-forest 20th frame
# finish merging 1-forest 21th frame
# finish merging 1-forest 22th frame
# finish merging 1-forest 23th frame
# finish merging 1-forest 24th frame
# finish merging 1-forest 25th frame
# finish merging 1-forest 26th frame
# finish merging 1-forest 27th frame
# finish merging 1-forest 28th frame
# finish merging 1-forest 29th frame
# finish merging 1-forest 30th frame
# finish merging 1-forest 31th frame
# finish merging 1-forest 32th frame
# finish merging 1-forest 33th frame
# finish merging 1-forest 34th frame
# finish merging 1-forest 35th frame
# finish merging 1-forest 36th frame
# finish merging 1-forest 37th frame
# finish merging 1-forest 38th frame
# finish merging 1-forest 39th frame
# finish merging 1-forest 40th frame
# finish merging 1-forest 41th frame
# finish merging 1-forest 42th frame
# finish merging 1-forest 43th frame
# finish merging 1-forest 44th frame
# finish merging 1-forest 45th frame
# finish merging 1-forest 46th frame
# finish merging 1-forest 47th frame
# finish merging 1-forest 48th frame
# finish merging 1-forest 49th frame
# finish merging 1-forest 50th frame
# finish merging 1-forest 51th frame
# finish merging 1-forest 52th frame
# finish merging 1-forest 53th frame
# finish merging 1-forest 54th frame
# finish merging 1-forest 55th frame
# finish merging 1-forest 56th frame
# finish merging 1-forest 57th frame
# finish merging 1-forest 58th frame
# finish merging 1-forest 59th frame
# finish merging 1-forest 60th frame
# finish merging 1-forest 61th frame
# finish merging 1-forest 62th frame
# finish merging 1-forest 63th frame
# finish merging 1-forest 64th frame
# finish merging 1-forest 65th frame
# finish merging 1-forest 66th frame
# finish merging 1-forest 67th frame
# finish merging 1-forest 68th frame
# finish merging 1-forest 69th frame
# finish merging 1-forest 70th frame
# finish merging 1-forest 71th frame
# finish merging 1-forest 72th frame
# finish merging 1-forest 73th frame
# finish merging 1-forest 74th frame
# finish merging 1-forest 75th frame
# finish merging 1-forest 76th frame
# finish merging 1-forest 77th frame
# finish merging 1-forest 78th frame
# finish merging 1-forest 79th frame
# finish merging 1-forest 80th frame
# finish merging 1-forest 81th frame
# finish merging 1-forest 82th frame
# finish merging 1-forest 83th frame
# finish merging 1-forest 84th frame
# finish merging 1-forest 85th frame
# finish merging 1-forest 86th frame
# finish merging 1-forest 87th frame
# finish merging 1-forest 88th frame
# finish merging 1-forest 89th frame
# finish merging 1-forest 90th frame
# finish merging 1-forest 91th frame
# finish merging 1-forest 92th frame
# finish merging 1-forest 93th frame
# finish merging 1-forest 94th frame
# finish merging 1-forest 95th frame
# finish merging 1-forest 96th frame
# finish merging 1-forest 97th frame
# finish merging 1-forest 98th frame
# finish merging 1-forest 99th frame
# finish merging 1-forest 100th frame
# finish merging 1-forest 101th frame
# finish merging 1-forest 102th frame
# finish merging 1-forest 103th frame
# finish merging 1-forest 104th frame
# finish merging 1-forest 105th frame
# finish merging 1-forest 106th frame
# finish merging 1-forest 107th frame
# finish merging 1-forest 108th frame
# finish merging 1-forest 109th frame
# finish merging 1-forest 110th frame
# finish merging 1-forest 111th frame
# finish merging 1-forest 112th frame
# finish merging 1-forest 113th frame
# finish merging 1-forest 114th frame
# finish merging 1-forest 115th frame
# finish merging 1-forest 116th frame
# finish merging 1-forest 117th frame
# finish merging 1-forest 118th frame
# finish merging 1-forest 119th frame
# finish merging 1-forest 120th frame
# finish merging 1-forest 121th frame
# finish merging 1-forest 122th frame
# finish merging 1-forest 123th frame
# finish merging 1-forest 124th frame
# finish merging 1-forest 125th frame
# finish merging 1-forest 126th frame
# finish merging 1-forest 127th frame
# finish merging 1-forest 128th frame
# finish merging 1-forest 129th frame
# finish merging 1-forest 130th frame
# finish merging 1-forest 131th frame
# finish merging 1-forest 132th frame
# finish merging 1-forest 133th frame
# finish merging 1-forest 134th frame
# finish merging 1-forest 135th frame
# finish merging 1-forest 136th frame
# finish merging 1-forest 137th frame
# finish merging 1-forest 138th frame
# finish merging 1-forest 139th frame
# finish merging 1-forest 140th frame
# finish merging 1-forest 141th frame
# finish merging 1-forest 142th frame
# finish merging 1-forest 143th frame
# finish merging 1-forest 144th frame
# finish merging 1-forest 145th frame
# finish merging 1-forest 146th frame
# finish merging 1-forest 147th frame
# finish merging 1-forest 148th frame
# finish merging 1-forest 149th frame
# finish merging 1-forest 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/forest-rep-reshape.tif
# finish merging 1-forest
# finish merging 2-Heron 1th frame
# finish merging 2-Heron 2th frame
# finish merging 2-Heron 3th frame
# finish merging 2-Heron 4th frame
# finish merging 2-Heron 5th frame
# finish merging 2-Heron 6th frame
# finish merging 2-Heron 7th frame
# finish merging 2-Heron 8th frame
# finish merging 2-Heron 9th frame
# finish merging 2-Heron 10th frame
# finish merging 2-Heron 11th frame
# finish merging 2-Heron 12th frame
# finish merging 2-Heron 13th frame
# finish merging 2-Heron 14th frame
# finish merging 2-Heron 15th frame
# finish merging 2-Heron 16th frame
# finish merging 2-Heron 17th frame
# finish merging 2-Heron 18th frame
# finish merging 2-Heron 19th frame
# finish merging 2-Heron 20th frame
# finish merging 2-Heron 21th frame
# finish merging 2-Heron 22th frame
# finish merging 2-Heron 23th frame
# finish merging 2-Heron 24th frame
# finish merging 2-Heron 25th frame
# finish merging 2-Heron 26th frame
# finish merging 2-Heron 27th frame
# finish merging 2-Heron 28th frame
# finish merging 2-Heron 29th frame
# finish merging 2-Heron 30th frame
# finish merging 2-Heron 31th frame
# finish merging 2-Heron 32th frame
# finish merging 2-Heron 33th frame
# finish merging 2-Heron 34th frame
# finish merging 2-Heron 35th frame
# finish merging 2-Heron 36th frame
# finish merging 2-Heron 37th frame
# finish merging 2-Heron 38th frame
# finish merging 2-Heron 39th frame
# finish merging 2-Heron 40th frame
# finish merging 2-Heron 41th frame
# finish merging 2-Heron 42th frame
# finish merging 2-Heron 43th frame
# finish merging 2-Heron 44th frame
# finish merging 2-Heron 45th frame
# finish merging 2-Heron 46th frame
# finish merging 2-Heron 47th frame
# finish merging 2-Heron 48th frame
# finish merging 2-Heron 49th frame
# finish merging 2-Heron 50th frame
# finish merging 2-Heron 51th frame
# finish merging 2-Heron 52th frame
# finish merging 2-Heron 53th frame
# finish merging 2-Heron 54th frame
# finish merging 2-Heron 55th frame
# finish merging 2-Heron 56th frame
# finish merging 2-Heron 57th frame
# finish merging 2-Heron 58th frame
# finish merging 2-Heron 59th frame
# finish merging 2-Heron 60th frame
# finish merging 2-Heron 61th frame
# finish merging 2-Heron 62th frame
# finish merging 2-Heron 63th frame
# finish merging 2-Heron 64th frame
# finish merging 2-Heron 65th frame
# finish merging 2-Heron 66th frame
# finish merging 2-Heron 67th frame
# finish merging 2-Heron 68th frame
# finish merging 2-Heron 69th frame
# finish merging 2-Heron 70th frame
# finish merging 2-Heron 71th frame
# finish merging 2-Heron 72th frame
# finish merging 2-Heron 73th frame
# finish merging 2-Heron 74th frame
# finish merging 2-Heron 75th frame
# finish merging 2-Heron 76th frame
# finish merging 2-Heron 77th frame
# finish merging 2-Heron 78th frame
# finish merging 2-Heron 79th frame
# finish merging 2-Heron 80th frame
# finish merging 2-Heron 81th frame
# finish merging 2-Heron 82th frame
# finish merging 2-Heron 83th frame
# finish merging 2-Heron 84th frame
# finish merging 2-Heron 85th frame
# finish merging 2-Heron 86th frame
# finish merging 2-Heron 87th frame
# finish merging 2-Heron 88th frame
# finish merging 2-Heron 89th frame
# finish merging 2-Heron 90th frame
# finish merging 2-Heron 91th frame
# finish merging 2-Heron 92th frame
# finish merging 2-Heron 93th frame
# finish merging 2-Heron 94th frame
# finish merging 2-Heron 95th frame
# finish merging 2-Heron 96th frame
# finish merging 2-Heron 97th frame
# finish merging 2-Heron 98th frame
# finish merging 2-Heron 99th frame
# finish merging 2-Heron 100th frame
# finish merging 2-Heron 101th frame
# finish merging 2-Heron 102th frame
# finish merging 2-Heron 103th frame
# finish merging 2-Heron 104th frame
# finish merging 2-Heron 105th frame
# finish merging 2-Heron 106th frame
# finish merging 2-Heron 107th frame
# finish merging 2-Heron 108th frame
# finish merging 2-Heron 109th frame
# finish merging 2-Heron 110th frame
# finish merging 2-Heron 111th frame
# finish merging 2-Heron 112th frame
# finish merging 2-Heron 113th frame
# finish merging 2-Heron 114th frame
# finish merging 2-Heron 115th frame
# finish merging 2-Heron 116th frame
# finish merging 2-Heron 117th frame
# finish merging 2-Heron 118th frame
# finish merging 2-Heron 119th frame
# finish merging 2-Heron 120th frame
# finish merging 2-Heron 121th frame
# finish merging 2-Heron 122th frame
# finish merging 2-Heron 123th frame
# finish merging 2-Heron 124th frame
# finish merging 2-Heron 125th frame
# finish merging 2-Heron 126th frame
# finish merging 2-Heron 127th frame
# finish merging 2-Heron 128th frame
# finish merging 2-Heron 129th frame
# finish merging 2-Heron 130th frame
# finish merging 2-Heron 131th frame
# finish merging 2-Heron 132th frame
# finish merging 2-Heron 133th frame
# finish merging 2-Heron 134th frame
# finish merging 2-Heron 135th frame
# finish merging 2-Heron 136th frame
# finish merging 2-Heron 137th frame
# finish merging 2-Heron 138th frame
# finish merging 2-Heron 139th frame
# finish merging 2-Heron 140th frame
# finish merging 2-Heron 141th frame
# finish merging 2-Heron 142th frame
# finish merging 2-Heron 143th frame
# finish merging 2-Heron 144th frame
# finish merging 2-Heron 145th frame
# finish merging 2-Heron 146th frame
# finish merging 2-Heron 147th frame
# finish merging 2-Heron 148th frame
# finish merging 2-Heron 149th frame
# finish merging 2-Heron 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/Heron-rep-reshape.tif
# finish merging 2-Heron
# finish merging 3-crow_peck_mouse1 1th frame
# finish merging 3-crow_peck_mouse1 2th frame
# finish merging 3-crow_peck_mouse1 3th frame
# finish merging 3-crow_peck_mouse1 4th frame
# finish merging 3-crow_peck_mouse1 5th frame
# finish merging 3-crow_peck_mouse1 6th frame
# finish merging 3-crow_peck_mouse1 7th frame
# finish merging 3-crow_peck_mouse1 8th frame
# finish merging 3-crow_peck_mouse1 9th frame
# finish merging 3-crow_peck_mouse1 10th frame
# finish merging 3-crow_peck_mouse1 11th frame
# finish merging 3-crow_peck_mouse1 12th frame
# finish merging 3-crow_peck_mouse1 13th frame
# finish merging 3-crow_peck_mouse1 14th frame
# finish merging 3-crow_peck_mouse1 15th frame
# finish merging 3-crow_peck_mouse1 16th frame
# finish merging 3-crow_peck_mouse1 17th frame
# finish merging 3-crow_peck_mouse1 18th frame
# finish merging 3-crow_peck_mouse1 19th frame
# finish merging 3-crow_peck_mouse1 20th frame
# finish merging 3-crow_peck_mouse1 21th frame
# finish merging 3-crow_peck_mouse1 22th frame
# finish merging 3-crow_peck_mouse1 23th frame
# finish merging 3-crow_peck_mouse1 24th frame
# finish merging 3-crow_peck_mouse1 25th frame
# finish merging 3-crow_peck_mouse1 26th frame
# finish merging 3-crow_peck_mouse1 27th frame
# finish merging 3-crow_peck_mouse1 28th frame
# finish merging 3-crow_peck_mouse1 29th frame
# finish merging 3-crow_peck_mouse1 30th frame
# finish merging 3-crow_peck_mouse1 31th frame
# finish merging 3-crow_peck_mouse1 32th frame
# finish merging 3-crow_peck_mouse1 33th frame
# finish merging 3-crow_peck_mouse1 34th frame
# finish merging 3-crow_peck_mouse1 35th frame
# finish merging 3-crow_peck_mouse1 36th frame
# finish merging 3-crow_peck_mouse1 37th frame
# finish merging 3-crow_peck_mouse1 38th frame
# finish merging 3-crow_peck_mouse1 39th frame
# finish merging 3-crow_peck_mouse1 40th frame
# finish merging 3-crow_peck_mouse1 41th frame
# finish merging 3-crow_peck_mouse1 42th frame
# finish merging 3-crow_peck_mouse1 43th frame
# finish merging 3-crow_peck_mouse1 44th frame
# finish merging 3-crow_peck_mouse1 45th frame
# finish merging 3-crow_peck_mouse1 46th frame
# finish merging 3-crow_peck_mouse1 47th frame
# finish merging 3-crow_peck_mouse1 48th frame
# finish merging 3-crow_peck_mouse1 49th frame
# finish merging 3-crow_peck_mouse1 50th frame
# finish merging 3-crow_peck_mouse1 51th frame
# finish merging 3-crow_peck_mouse1 52th frame
# finish merging 3-crow_peck_mouse1 53th frame
# finish merging 3-crow_peck_mouse1 54th frame
# finish merging 3-crow_peck_mouse1 55th frame
# finish merging 3-crow_peck_mouse1 56th frame
# finish merging 3-crow_peck_mouse1 57th frame
# finish merging 3-crow_peck_mouse1 58th frame
# finish merging 3-crow_peck_mouse1 59th frame
# finish merging 3-crow_peck_mouse1 60th frame
# finish merging 3-crow_peck_mouse1 61th frame
# finish merging 3-crow_peck_mouse1 62th frame
# finish merging 3-crow_peck_mouse1 63th frame
# finish merging 3-crow_peck_mouse1 64th frame
# finish merging 3-crow_peck_mouse1 65th frame
# finish merging 3-crow_peck_mouse1 66th frame
# finish merging 3-crow_peck_mouse1 67th frame
# finish merging 3-crow_peck_mouse1 68th frame
# finish merging 3-crow_peck_mouse1 69th frame
# finish merging 3-crow_peck_mouse1 70th frame
# finish merging 3-crow_peck_mouse1 71th frame
# finish merging 3-crow_peck_mouse1 72th frame
# finish merging 3-crow_peck_mouse1 73th frame
# finish merging 3-crow_peck_mouse1 74th frame
# finish merging 3-crow_peck_mouse1 75th frame
# finish merging 3-crow_peck_mouse1 76th frame
# finish merging 3-crow_peck_mouse1 77th frame
# finish merging 3-crow_peck_mouse1 78th frame
# finish merging 3-crow_peck_mouse1 79th frame
# finish merging 3-crow_peck_mouse1 80th frame
# finish merging 3-crow_peck_mouse1 81th frame
# finish merging 3-crow_peck_mouse1 82th frame
# finish merging 3-crow_peck_mouse1 83th frame
# finish merging 3-crow_peck_mouse1 84th frame
# finish merging 3-crow_peck_mouse1 85th frame
# finish merging 3-crow_peck_mouse1 86th frame
# finish merging 3-crow_peck_mouse1 87th frame
# finish merging 3-crow_peck_mouse1 88th frame
# finish merging 3-crow_peck_mouse1 89th frame
# finish merging 3-crow_peck_mouse1 90th frame
# finish merging 3-crow_peck_mouse1 91th frame
# finish merging 3-crow_peck_mouse1 92th frame
# finish merging 3-crow_peck_mouse1 93th frame
# finish merging 3-crow_peck_mouse1 94th frame
# finish merging 3-crow_peck_mouse1 95th frame
# finish merging 3-crow_peck_mouse1 96th frame
# finish merging 3-crow_peck_mouse1 97th frame
# finish merging 3-crow_peck_mouse1 98th frame
# finish merging 3-crow_peck_mouse1 99th frame
# finish merging 3-crow_peck_mouse1 100th frame
# finish merging 3-crow_peck_mouse1 101th frame
# finish merging 3-crow_peck_mouse1 102th frame
# finish merging 3-crow_peck_mouse1 103th frame
# finish merging 3-crow_peck_mouse1 104th frame
# finish merging 3-crow_peck_mouse1 105th frame
# finish merging 3-crow_peck_mouse1 106th frame
# finish merging 3-crow_peck_mouse1 107th frame
# finish merging 3-crow_peck_mouse1 108th frame
# finish merging 3-crow_peck_mouse1 109th frame
# finish merging 3-crow_peck_mouse1 110th frame
# finish merging 3-crow_peck_mouse1 111th frame
# finish merging 3-crow_peck_mouse1 112th frame
# finish merging 3-crow_peck_mouse1 113th frame
# finish merging 3-crow_peck_mouse1 114th frame
# finish merging 3-crow_peck_mouse1 115th frame
# finish merging 3-crow_peck_mouse1 116th frame
# finish merging 3-crow_peck_mouse1 117th frame
# finish merging 3-crow_peck_mouse1 118th frame
# finish merging 3-crow_peck_mouse1 119th frame
# finish merging 3-crow_peck_mouse1 120th frame
# finish merging 3-crow_peck_mouse1 121th frame
# finish merging 3-crow_peck_mouse1 122th frame
# finish merging 3-crow_peck_mouse1 123th frame
# finish merging 3-crow_peck_mouse1 124th frame
# finish merging 3-crow_peck_mouse1 125th frame
# finish merging 3-crow_peck_mouse1 126th frame
# finish merging 3-crow_peck_mouse1 127th frame
# finish merging 3-crow_peck_mouse1 128th frame
# finish merging 3-crow_peck_mouse1 129th frame
# finish merging 3-crow_peck_mouse1 130th frame
# finish merging 3-crow_peck_mouse1 131th frame
# finish merging 3-crow_peck_mouse1 132th frame
# finish merging 3-crow_peck_mouse1 133th frame
# finish merging 3-crow_peck_mouse1 134th frame
# finish merging 3-crow_peck_mouse1 135th frame
# finish merging 3-crow_peck_mouse1 136th frame
# finish merging 3-crow_peck_mouse1 137th frame
# finish merging 3-crow_peck_mouse1 138th frame
# finish merging 3-crow_peck_mouse1 139th frame
# finish merging 3-crow_peck_mouse1 140th frame
# finish merging 3-crow_peck_mouse1 141th frame
# finish merging 3-crow_peck_mouse1 142th frame
# finish merging 3-crow_peck_mouse1 143th frame
# finish merging 3-crow_peck_mouse1 144th frame
# finish merging 3-crow_peck_mouse1 145th frame
# finish merging 3-crow_peck_mouse1 146th frame
# finish merging 3-crow_peck_mouse1 147th frame
# finish merging 3-crow_peck_mouse1 148th frame
# finish merging 3-crow_peck_mouse1 149th frame
# finish merging 3-crow_peck_mouse1 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/crow_peck_mouse1-rep-reshape.tif
# finish merging 3-crow_peck_mouse1
# finish merging 4-owl_peck 1th frame
# finish merging 4-owl_peck 2th frame
# finish merging 4-owl_peck 3th frame
# finish merging 4-owl_peck 4th frame
# finish merging 4-owl_peck 5th frame
# finish merging 4-owl_peck 6th frame
# finish merging 4-owl_peck 7th frame
# finish merging 4-owl_peck 8th frame
# finish merging 4-owl_peck 9th frame
# finish merging 4-owl_peck 10th frame
# finish merging 4-owl_peck 11th frame
# finish merging 4-owl_peck 12th frame
# finish merging 4-owl_peck 13th frame
# finish merging 4-owl_peck 14th frame
# finish merging 4-owl_peck 15th frame
# finish merging 4-owl_peck 16th frame
# finish merging 4-owl_peck 17th frame
# finish merging 4-owl_peck 18th frame
# finish merging 4-owl_peck 19th frame
# finish merging 4-owl_peck 20th frame
# finish merging 4-owl_peck 21th frame
# finish merging 4-owl_peck 22th frame
# finish merging 4-owl_peck 23th frame
# finish merging 4-owl_peck 24th frame
# finish merging 4-owl_peck 25th frame
# finish merging 4-owl_peck 26th frame
# finish merging 4-owl_peck 27th frame
# finish merging 4-owl_peck 28th frame
# finish merging 4-owl_peck 29th frame
# finish merging 4-owl_peck 30th frame
# finish merging 4-owl_peck 31th frame
# finish merging 4-owl_peck 32th frame
# finish merging 4-owl_peck 33th frame
# finish merging 4-owl_peck 34th frame
# finish merging 4-owl_peck 35th frame
# finish merging 4-owl_peck 36th frame
# finish merging 4-owl_peck 37th frame
# finish merging 4-owl_peck 38th frame
# finish merging 4-owl_peck 39th frame
# finish merging 4-owl_peck 40th frame
# finish merging 4-owl_peck 41th frame
# finish merging 4-owl_peck 42th frame
# finish merging 4-owl_peck 43th frame
# finish merging 4-owl_peck 44th frame
# finish merging 4-owl_peck 45th frame
# finish merging 4-owl_peck 46th frame
# finish merging 4-owl_peck 47th frame
# finish merging 4-owl_peck 48th frame
# finish merging 4-owl_peck 49th frame
# finish merging 4-owl_peck 50th frame
# finish merging 4-owl_peck 51th frame
# finish merging 4-owl_peck 52th frame
# finish merging 4-owl_peck 53th frame
# finish merging 4-owl_peck 54th frame
# finish merging 4-owl_peck 55th frame
# finish merging 4-owl_peck 56th frame
# finish merging 4-owl_peck 57th frame
# finish merging 4-owl_peck 58th frame
# finish merging 4-owl_peck 59th frame
# finish merging 4-owl_peck 60th frame
# finish merging 4-owl_peck 61th frame
# finish merging 4-owl_peck 62th frame
# finish merging 4-owl_peck 63th frame
# finish merging 4-owl_peck 64th frame
# finish merging 4-owl_peck 65th frame
# finish merging 4-owl_peck 66th frame
# finish merging 4-owl_peck 67th frame
# finish merging 4-owl_peck 68th frame
# finish merging 4-owl_peck 69th frame
# finish merging 4-owl_peck 70th frame
# finish merging 4-owl_peck 71th frame
# finish merging 4-owl_peck 72th frame
# finish merging 4-owl_peck 73th frame
# finish merging 4-owl_peck 74th frame
# finish merging 4-owl_peck 75th frame
# finish merging 4-owl_peck 76th frame
# finish merging 4-owl_peck 77th frame
# finish merging 4-owl_peck 78th frame
# finish merging 4-owl_peck 79th frame
# finish merging 4-owl_peck 80th frame
# finish merging 4-owl_peck 81th frame
# finish merging 4-owl_peck 82th frame
# finish merging 4-owl_peck 83th frame
# finish merging 4-owl_peck 84th frame
# finish merging 4-owl_peck 85th frame
# finish merging 4-owl_peck 86th frame
# finish merging 4-owl_peck 87th frame
# finish merging 4-owl_peck 88th frame
# finish merging 4-owl_peck 89th frame
# finish merging 4-owl_peck 90th frame
# finish merging 4-owl_peck 91th frame
# finish merging 4-owl_peck 92th frame
# finish merging 4-owl_peck 93th frame
# finish merging 4-owl_peck 94th frame
# finish merging 4-owl_peck 95th frame
# finish merging 4-owl_peck 96th frame
# finish merging 4-owl_peck 97th frame
# finish merging 4-owl_peck 98th frame
# finish merging 4-owl_peck 99th frame
# finish merging 4-owl_peck 100th frame
# finish merging 4-owl_peck 101th frame
# finish merging 4-owl_peck 102th frame
# finish merging 4-owl_peck 103th frame
# finish merging 4-owl_peck 104th frame
# finish merging 4-owl_peck 105th frame
# finish merging 4-owl_peck 106th frame
# finish merging 4-owl_peck 107th frame
# finish merging 4-owl_peck 108th frame
# finish merging 4-owl_peck 109th frame
# finish merging 4-owl_peck 110th frame
# finish merging 4-owl_peck 111th frame
# finish merging 4-owl_peck 112th frame
# finish merging 4-owl_peck 113th frame
# finish merging 4-owl_peck 114th frame
# finish merging 4-owl_peck 115th frame
# finish merging 4-owl_peck 116th frame
# finish merging 4-owl_peck 117th frame
# finish merging 4-owl_peck 118th frame
# finish merging 4-owl_peck 119th frame
# finish merging 4-owl_peck 120th frame
# finish merging 4-owl_peck 121th frame
# finish merging 4-owl_peck 122th frame
# finish merging 4-owl_peck 123th frame
# finish merging 4-owl_peck 124th frame
# finish merging 4-owl_peck 125th frame
# finish merging 4-owl_peck 126th frame
# finish merging 4-owl_peck 127th frame
# finish merging 4-owl_peck 128th frame
# finish merging 4-owl_peck 129th frame
# finish merging 4-owl_peck 130th frame
# finish merging 4-owl_peck 131th frame
# finish merging 4-owl_peck 132th frame
# finish merging 4-owl_peck 133th frame
# finish merging 4-owl_peck 134th frame
# finish merging 4-owl_peck 135th frame
# finish merging 4-owl_peck 136th frame
# finish merging 4-owl_peck 137th frame
# finish merging 4-owl_peck 138th frame
# finish merging 4-owl_peck 139th frame
# finish merging 4-owl_peck 140th frame
# finish merging 4-owl_peck 141th frame
# finish merging 4-owl_peck 142th frame
# finish merging 4-owl_peck 143th frame
# finish merging 4-owl_peck 144th frame
# finish merging 4-owl_peck 145th frame
# finish merging 4-owl_peck 146th frame
# finish merging 4-owl_peck 147th frame
# finish merging 4-owl_peck 148th frame
# finish merging 4-owl_peck 149th frame
# finish merging 4-owl_peck 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/owl_peck-rep-reshape.tif
# finish merging 4-owl_peck
# finish merging 5-cat 1th frame
# finish merging 5-cat 2th frame
# finish merging 5-cat 3th frame
# finish merging 5-cat 4th frame
# finish merging 5-cat 5th frame
# finish merging 5-cat 6th frame
# finish merging 5-cat 7th frame
# finish merging 5-cat 8th frame
# finish merging 5-cat 9th frame
# finish merging 5-cat 10th frame
# finish merging 5-cat 11th frame
# finish merging 5-cat 12th frame
# finish merging 5-cat 13th frame
# finish merging 5-cat 14th frame
# finish merging 5-cat 15th frame
# finish merging 5-cat 16th frame
# finish merging 5-cat 17th frame
# finish merging 5-cat 18th frame
# finish merging 5-cat 19th frame
# finish merging 5-cat 20th frame
# finish merging 5-cat 21th frame
# finish merging 5-cat 22th frame
# finish merging 5-cat 23th frame
# finish merging 5-cat 24th frame
# finish merging 5-cat 25th frame
# finish merging 5-cat 26th frame
# finish merging 5-cat 27th frame
# finish merging 5-cat 28th frame
# finish merging 5-cat 29th frame
# finish merging 5-cat 30th frame
# finish merging 5-cat 31th frame
# finish merging 5-cat 32th frame
# finish merging 5-cat 33th frame
# finish merging 5-cat 34th frame
# finish merging 5-cat 35th frame
# finish merging 5-cat 36th frame
# finish merging 5-cat 37th frame
# finish merging 5-cat 38th frame
# finish merging 5-cat 39th frame
# finish merging 5-cat 40th frame
# finish merging 5-cat 41th frame
# finish merging 5-cat 42th frame
# finish merging 5-cat 43th frame
# finish merging 5-cat 44th frame
# finish merging 5-cat 45th frame
# finish merging 5-cat 46th frame
# finish merging 5-cat 47th frame
# finish merging 5-cat 48th frame
# finish merging 5-cat 49th frame
# finish merging 5-cat 50th frame
# finish merging 5-cat 51th frame
# finish merging 5-cat 52th frame
# finish merging 5-cat 53th frame
# finish merging 5-cat 54th frame
# finish merging 5-cat 55th frame
# finish merging 5-cat 56th frame
# finish merging 5-cat 57th frame
# finish merging 5-cat 58th frame
# finish merging 5-cat 59th frame
# finish merging 5-cat 60th frame
# finish merging 5-cat 61th frame
# finish merging 5-cat 62th frame
# finish merging 5-cat 63th frame
# finish merging 5-cat 64th frame
# finish merging 5-cat 65th frame
# finish merging 5-cat 66th frame
# finish merging 5-cat 67th frame
# finish merging 5-cat 68th frame
# finish merging 5-cat 69th frame
# finish merging 5-cat 70th frame
# finish merging 5-cat 71th frame
# finish merging 5-cat 72th frame
# finish merging 5-cat 73th frame
# finish merging 5-cat 74th frame
# finish merging 5-cat 75th frame
# finish merging 5-cat 76th frame
# finish merging 5-cat 77th frame
# finish merging 5-cat 78th frame
# finish merging 5-cat 79th frame
# finish merging 5-cat 80th frame
# finish merging 5-cat 81th frame
# finish merging 5-cat 82th frame
# finish merging 5-cat 83th frame
# finish merging 5-cat 84th frame
# finish merging 5-cat 85th frame
# finish merging 5-cat 86th frame
# finish merging 5-cat 87th frame
# finish merging 5-cat 88th frame
# finish merging 5-cat 89th frame
# finish merging 5-cat 90th frame
# finish merging 5-cat 91th frame
# finish merging 5-cat 92th frame
# finish merging 5-cat 93th frame
# finish merging 5-cat 94th frame
# finish merging 5-cat 95th frame
# finish merging 5-cat 96th frame
# finish merging 5-cat 97th frame
# finish merging 5-cat 98th frame
# finish merging 5-cat 99th frame
# finish merging 5-cat 100th frame
# finish merging 5-cat 101th frame
# finish merging 5-cat 102th frame
# finish merging 5-cat 103th frame
# finish merging 5-cat 104th frame
# finish merging 5-cat 105th frame
# finish merging 5-cat 106th frame
# finish merging 5-cat 107th frame
# finish merging 5-cat 108th frame
# finish merging 5-cat 109th frame
# finish merging 5-cat 110th frame
# finish merging 5-cat 111th frame
# finish merging 5-cat 112th frame
# finish merging 5-cat 113th frame
# finish merging 5-cat 114th frame
# finish merging 5-cat 115th frame
# finish merging 5-cat 116th frame
# finish merging 5-cat 117th frame
# finish merging 5-cat 118th frame
# finish merging 5-cat 119th frame
# finish merging 5-cat 120th frame
# finish merging 5-cat 121th frame
# finish merging 5-cat 122th frame
# finish merging 5-cat 123th frame
# finish merging 5-cat 124th frame
# finish merging 5-cat 125th frame
# finish merging 5-cat 126th frame
# finish merging 5-cat 127th frame
# finish merging 5-cat 128th frame
# finish merging 5-cat 129th frame
# finish merging 5-cat 130th frame
# finish merging 5-cat 131th frame
# finish merging 5-cat 132th frame
# finish merging 5-cat 133th frame
# finish merging 5-cat 134th frame
# finish merging 5-cat 135th frame
# finish merging 5-cat 136th frame
# finish merging 5-cat 137th frame
# finish merging 5-cat 138th frame
# finish merging 5-cat 139th frame
# finish merging 5-cat 140th frame
# finish merging 5-cat 141th frame
# finish merging 5-cat 142th frame
# finish merging 5-cat 143th frame
# finish merging 5-cat 144th frame
# finish merging 5-cat 145th frame
# finish merging 5-cat 146th frame
# finish merging 5-cat 147th frame
# finish merging 5-cat 148th frame
# finish merging 5-cat 149th frame
# finish merging 5-cat 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/cat-rep-reshape.tif
# finish merging 5-cat
# finish merging 6-cat_catch_mouse1 1th frame
# finish merging 6-cat_catch_mouse1 2th frame
# finish merging 6-cat_catch_mouse1 3th frame
# finish merging 6-cat_catch_mouse1 4th frame
# finish merging 6-cat_catch_mouse1 5th frame
# finish merging 6-cat_catch_mouse1 6th frame
# finish merging 6-cat_catch_mouse1 7th frame
# finish merging 6-cat_catch_mouse1 8th frame
# finish merging 6-cat_catch_mouse1 9th frame
# finish merging 6-cat_catch_mouse1 10th frame
# finish merging 6-cat_catch_mouse1 11th frame
# finish merging 6-cat_catch_mouse1 12th frame
# finish merging 6-cat_catch_mouse1 13th frame
# finish merging 6-cat_catch_mouse1 14th frame
# finish merging 6-cat_catch_mouse1 15th frame
# finish merging 6-cat_catch_mouse1 16th frame
# finish merging 6-cat_catch_mouse1 17th frame
# finish merging 6-cat_catch_mouse1 18th frame
# finish merging 6-cat_catch_mouse1 19th frame
# finish merging 6-cat_catch_mouse1 20th frame
# finish merging 6-cat_catch_mouse1 21th frame
# finish merging 6-cat_catch_mouse1 22th frame
# finish merging 6-cat_catch_mouse1 23th frame
# finish merging 6-cat_catch_mouse1 24th frame
# finish merging 6-cat_catch_mouse1 25th frame
# finish merging 6-cat_catch_mouse1 26th frame
# finish merging 6-cat_catch_mouse1 27th frame
# finish merging 6-cat_catch_mouse1 28th frame
# finish merging 6-cat_catch_mouse1 29th frame
# finish merging 6-cat_catch_mouse1 30th frame
# finish merging 6-cat_catch_mouse1 31th frame
# finish merging 6-cat_catch_mouse1 32th frame
# finish merging 6-cat_catch_mouse1 33th frame
# finish merging 6-cat_catch_mouse1 34th frame
# finish merging 6-cat_catch_mouse1 35th frame
# finish merging 6-cat_catch_mouse1 36th frame
# finish merging 6-cat_catch_mouse1 37th frame
# finish merging 6-cat_catch_mouse1 38th frame
# finish merging 6-cat_catch_mouse1 39th frame
# finish merging 6-cat_catch_mouse1 40th frame
# finish merging 6-cat_catch_mouse1 41th frame
# finish merging 6-cat_catch_mouse1 42th frame
# finish merging 6-cat_catch_mouse1 43th frame
# finish merging 6-cat_catch_mouse1 44th frame
# finish merging 6-cat_catch_mouse1 45th frame
# finish merging 6-cat_catch_mouse1 46th frame
# finish merging 6-cat_catch_mouse1 47th frame
# finish merging 6-cat_catch_mouse1 48th frame
# finish merging 6-cat_catch_mouse1 49th frame
# finish merging 6-cat_catch_mouse1 50th frame
# finish merging 6-cat_catch_mouse1 51th frame
# finish merging 6-cat_catch_mouse1 52th frame
# finish merging 6-cat_catch_mouse1 53th frame
# finish merging 6-cat_catch_mouse1 54th frame
# finish merging 6-cat_catch_mouse1 55th frame
# finish merging 6-cat_catch_mouse1 56th frame
# finish merging 6-cat_catch_mouse1 57th frame
# finish merging 6-cat_catch_mouse1 58th frame
# finish merging 6-cat_catch_mouse1 59th frame
# finish merging 6-cat_catch_mouse1 60th frame
# finish merging 6-cat_catch_mouse1 61th frame
# finish merging 6-cat_catch_mouse1 62th frame
# finish merging 6-cat_catch_mouse1 63th frame
# finish merging 6-cat_catch_mouse1 64th frame
# finish merging 6-cat_catch_mouse1 65th frame
# finish merging 6-cat_catch_mouse1 66th frame
# finish merging 6-cat_catch_mouse1 67th frame
# finish merging 6-cat_catch_mouse1 68th frame
# finish merging 6-cat_catch_mouse1 69th frame
# finish merging 6-cat_catch_mouse1 70th frame
# finish merging 6-cat_catch_mouse1 71th frame
# finish merging 6-cat_catch_mouse1 72th frame
# finish merging 6-cat_catch_mouse1 73th frame
# finish merging 6-cat_catch_mouse1 74th frame
# finish merging 6-cat_catch_mouse1 75th frame
# finish merging 6-cat_catch_mouse1 76th frame
# finish merging 6-cat_catch_mouse1 77th frame
# finish merging 6-cat_catch_mouse1 78th frame
# finish merging 6-cat_catch_mouse1 79th frame
# finish merging 6-cat_catch_mouse1 80th frame
# finish merging 6-cat_catch_mouse1 81th frame
# finish merging 6-cat_catch_mouse1 82th frame
# finish merging 6-cat_catch_mouse1 83th frame
# finish merging 6-cat_catch_mouse1 84th frame
# finish merging 6-cat_catch_mouse1 85th frame
# finish merging 6-cat_catch_mouse1 86th frame
# finish merging 6-cat_catch_mouse1 87th frame
# finish merging 6-cat_catch_mouse1 88th frame
# finish merging 6-cat_catch_mouse1 89th frame
# finish merging 6-cat_catch_mouse1 90th frame
# finish merging 6-cat_catch_mouse1 91th frame
# finish merging 6-cat_catch_mouse1 92th frame
# finish merging 6-cat_catch_mouse1 93th frame
# finish merging 6-cat_catch_mouse1 94th frame
# finish merging 6-cat_catch_mouse1 95th frame
# finish merging 6-cat_catch_mouse1 96th frame
# finish merging 6-cat_catch_mouse1 97th frame
# finish merging 6-cat_catch_mouse1 98th frame
# finish merging 6-cat_catch_mouse1 99th frame
# finish merging 6-cat_catch_mouse1 100th frame
# finish merging 6-cat_catch_mouse1 101th frame
# finish merging 6-cat_catch_mouse1 102th frame
# finish merging 6-cat_catch_mouse1 103th frame
# finish merging 6-cat_catch_mouse1 104th frame
# finish merging 6-cat_catch_mouse1 105th frame
# finish merging 6-cat_catch_mouse1 106th frame
# finish merging 6-cat_catch_mouse1 107th frame
# finish merging 6-cat_catch_mouse1 108th frame
# finish merging 6-cat_catch_mouse1 109th frame
# finish merging 6-cat_catch_mouse1 110th frame
# finish merging 6-cat_catch_mouse1 111th frame
# finish merging 6-cat_catch_mouse1 112th frame
# finish merging 6-cat_catch_mouse1 113th frame
# finish merging 6-cat_catch_mouse1 114th frame
# finish merging 6-cat_catch_mouse1 115th frame
# finish merging 6-cat_catch_mouse1 116th frame
# finish merging 6-cat_catch_mouse1 117th frame
# finish merging 6-cat_catch_mouse1 118th frame
# finish merging 6-cat_catch_mouse1 119th frame
# finish merging 6-cat_catch_mouse1 120th frame
# finish merging 6-cat_catch_mouse1 121th frame
# finish merging 6-cat_catch_mouse1 122th frame
# finish merging 6-cat_catch_mouse1 123th frame
# finish merging 6-cat_catch_mouse1 124th frame
# finish merging 6-cat_catch_mouse1 125th frame
# finish merging 6-cat_catch_mouse1 126th frame
# finish merging 6-cat_catch_mouse1 127th frame
# finish merging 6-cat_catch_mouse1 128th frame
# finish merging 6-cat_catch_mouse1 129th frame
# finish merging 6-cat_catch_mouse1 130th frame
# finish merging 6-cat_catch_mouse1 131th frame
# finish merging 6-cat_catch_mouse1 132th frame
# finish merging 6-cat_catch_mouse1 133th frame
# finish merging 6-cat_catch_mouse1 134th frame
# finish merging 6-cat_catch_mouse1 135th frame
# finish merging 6-cat_catch_mouse1 136th frame
# finish merging 6-cat_catch_mouse1 137th frame
# finish merging 6-cat_catch_mouse1 138th frame
# finish merging 6-cat_catch_mouse1 139th frame
# finish merging 6-cat_catch_mouse1 140th frame
# finish merging 6-cat_catch_mouse1 141th frame
# finish merging 6-cat_catch_mouse1 142th frame
# finish merging 6-cat_catch_mouse1 143th frame
# finish merging 6-cat_catch_mouse1 144th frame
# finish merging 6-cat_catch_mouse1 145th frame
# finish merging 6-cat_catch_mouse1 146th frame
# finish merging 6-cat_catch_mouse1 147th frame
# finish merging 6-cat_catch_mouse1 148th frame
# finish merging 6-cat_catch_mouse1 149th frame
# finish merging 6-cat_catch_mouse1 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/cat_catch_mouse1-rep-reshape.tif
# finish merging 6-cat_catch_mouse1
# finish merging 7-cat_eat_mouse 1th frame
# finish merging 7-cat_eat_mouse 2th frame
# finish merging 7-cat_eat_mouse 3th frame
# finish merging 7-cat_eat_mouse 4th frame
# finish merging 7-cat_eat_mouse 5th frame
# finish merging 7-cat_eat_mouse 6th frame
# finish merging 7-cat_eat_mouse 7th frame
# finish merging 7-cat_eat_mouse 8th frame
# finish merging 7-cat_eat_mouse 9th frame
# finish merging 7-cat_eat_mouse 10th frame
# finish merging 7-cat_eat_mouse 11th frame
# finish merging 7-cat_eat_mouse 12th frame
# finish merging 7-cat_eat_mouse 13th frame
# finish merging 7-cat_eat_mouse 14th frame
# finish merging 7-cat_eat_mouse 15th frame
# finish merging 7-cat_eat_mouse 16th frame
# finish merging 7-cat_eat_mouse 17th frame
# finish merging 7-cat_eat_mouse 18th frame
# finish merging 7-cat_eat_mouse 19th frame
# finish merging 7-cat_eat_mouse 20th frame
# finish merging 7-cat_eat_mouse 21th frame
# finish merging 7-cat_eat_mouse 22th frame
# finish merging 7-cat_eat_mouse 23th frame
# finish merging 7-cat_eat_mouse 24th frame
# finish merging 7-cat_eat_mouse 25th frame
# finish merging 7-cat_eat_mouse 26th frame
# finish merging 7-cat_eat_mouse 27th frame
# finish merging 7-cat_eat_mouse 28th frame
# finish merging 7-cat_eat_mouse 29th frame
# finish merging 7-cat_eat_mouse 30th frame
# finish merging 7-cat_eat_mouse 31th frame
# finish merging 7-cat_eat_mouse 32th frame
# finish merging 7-cat_eat_mouse 33th frame
# finish merging 7-cat_eat_mouse 34th frame
# finish merging 7-cat_eat_mouse 35th frame
# finish merging 7-cat_eat_mouse 36th frame
# finish merging 7-cat_eat_mouse 37th frame
# finish merging 7-cat_eat_mouse 38th frame
# finish merging 7-cat_eat_mouse 39th frame
# finish merging 7-cat_eat_mouse 40th frame
# finish merging 7-cat_eat_mouse 41th frame
# finish merging 7-cat_eat_mouse 42th frame
# finish merging 7-cat_eat_mouse 43th frame
# finish merging 7-cat_eat_mouse 44th frame
# finish merging 7-cat_eat_mouse 45th frame
# finish merging 7-cat_eat_mouse 46th frame
# finish merging 7-cat_eat_mouse 47th frame
# finish merging 7-cat_eat_mouse 48th frame
# finish merging 7-cat_eat_mouse 49th frame
# finish merging 7-cat_eat_mouse 50th frame
# finish merging 7-cat_eat_mouse 51th frame
# finish merging 7-cat_eat_mouse 52th frame
# finish merging 7-cat_eat_mouse 53th frame
# finish merging 7-cat_eat_mouse 54th frame
# finish merging 7-cat_eat_mouse 55th frame
# finish merging 7-cat_eat_mouse 56th frame
# finish merging 7-cat_eat_mouse 57th frame
# finish merging 7-cat_eat_mouse 58th frame
# finish merging 7-cat_eat_mouse 59th frame
# finish merging 7-cat_eat_mouse 60th frame
# finish merging 7-cat_eat_mouse 61th frame
# finish merging 7-cat_eat_mouse 62th frame
# finish merging 7-cat_eat_mouse 63th frame
# finish merging 7-cat_eat_mouse 64th frame
# finish merging 7-cat_eat_mouse 65th frame
# finish merging 7-cat_eat_mouse 66th frame
# finish merging 7-cat_eat_mouse 67th frame
# finish merging 7-cat_eat_mouse 68th frame
# finish merging 7-cat_eat_mouse 69th frame
# finish merging 7-cat_eat_mouse 70th frame
# finish merging 7-cat_eat_mouse 71th frame
# finish merging 7-cat_eat_mouse 72th frame
# finish merging 7-cat_eat_mouse 73th frame
# finish merging 7-cat_eat_mouse 74th frame
# finish merging 7-cat_eat_mouse 75th frame
# finish merging 7-cat_eat_mouse 76th frame
# finish merging 7-cat_eat_mouse 77th frame
# finish merging 7-cat_eat_mouse 78th frame
# finish merging 7-cat_eat_mouse 79th frame
# finish merging 7-cat_eat_mouse 80th frame
# finish merging 7-cat_eat_mouse 81th frame
# finish merging 7-cat_eat_mouse 82th frame
# finish merging 7-cat_eat_mouse 83th frame
# finish merging 7-cat_eat_mouse 84th frame
# finish merging 7-cat_eat_mouse 85th frame
# finish merging 7-cat_eat_mouse 86th frame
# finish merging 7-cat_eat_mouse 87th frame
# finish merging 7-cat_eat_mouse 88th frame
# finish merging 7-cat_eat_mouse 89th frame
# finish merging 7-cat_eat_mouse 90th frame
# finish merging 7-cat_eat_mouse 91th frame
# finish merging 7-cat_eat_mouse 92th frame
# finish merging 7-cat_eat_mouse 93th frame
# finish merging 7-cat_eat_mouse 94th frame
# finish merging 7-cat_eat_mouse 95th frame
# finish merging 7-cat_eat_mouse 96th frame
# finish merging 7-cat_eat_mouse 97th frame
# finish merging 7-cat_eat_mouse 98th frame
# finish merging 7-cat_eat_mouse 99th frame
# finish merging 7-cat_eat_mouse 100th frame
# finish merging 7-cat_eat_mouse 101th frame
# finish merging 7-cat_eat_mouse 102th frame
# finish merging 7-cat_eat_mouse 103th frame
# finish merging 7-cat_eat_mouse 104th frame
# finish merging 7-cat_eat_mouse 105th frame
# finish merging 7-cat_eat_mouse 106th frame
# finish merging 7-cat_eat_mouse 107th frame
# finish merging 7-cat_eat_mouse 108th frame
# finish merging 7-cat_eat_mouse 109th frame
# finish merging 7-cat_eat_mouse 110th frame
# finish merging 7-cat_eat_mouse 111th frame
# finish merging 7-cat_eat_mouse 112th frame
# finish merging 7-cat_eat_mouse 113th frame
# finish merging 7-cat_eat_mouse 114th frame
# finish merging 7-cat_eat_mouse 115th frame
# finish merging 7-cat_eat_mouse 116th frame
# finish merging 7-cat_eat_mouse 117th frame
# finish merging 7-cat_eat_mouse 118th frame
# finish merging 7-cat_eat_mouse 119th frame
# finish merging 7-cat_eat_mouse 120th frame
# finish merging 7-cat_eat_mouse 121th frame
# finish merging 7-cat_eat_mouse 122th frame
# finish merging 7-cat_eat_mouse 123th frame
# finish merging 7-cat_eat_mouse 124th frame
# finish merging 7-cat_eat_mouse 125th frame
# finish merging 7-cat_eat_mouse 126th frame
# finish merging 7-cat_eat_mouse 127th frame
# finish merging 7-cat_eat_mouse 128th frame
# finish merging 7-cat_eat_mouse 129th frame
# finish merging 7-cat_eat_mouse 130th frame
# finish merging 7-cat_eat_mouse 131th frame
# finish merging 7-cat_eat_mouse 132th frame
# finish merging 7-cat_eat_mouse 133th frame
# finish merging 7-cat_eat_mouse 134th frame
# finish merging 7-cat_eat_mouse 135th frame
# finish merging 7-cat_eat_mouse 136th frame
# finish merging 7-cat_eat_mouse 137th frame
# finish merging 7-cat_eat_mouse 138th frame
# finish merging 7-cat_eat_mouse 139th frame
# finish merging 7-cat_eat_mouse 140th frame
# finish merging 7-cat_eat_mouse 141th frame
# finish merging 7-cat_eat_mouse 142th frame
# finish merging 7-cat_eat_mouse 143th frame
# finish merging 7-cat_eat_mouse 144th frame
# finish merging 7-cat_eat_mouse 145th frame
# finish merging 7-cat_eat_mouse 146th frame
# finish merging 7-cat_eat_mouse 147th frame
# finish merging 7-cat_eat_mouse 148th frame
# finish merging 7-cat_eat_mouse 149th frame
# finish merging 7-cat_eat_mouse 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/cat_eat_mouse-rep-reshape.tif
# finish merging 7-cat_eat_mouse
# finish merging 8-cat_pat 1th frame
# finish merging 8-cat_pat 2th frame
# finish merging 8-cat_pat 3th frame
# finish merging 8-cat_pat 4th frame
# finish merging 8-cat_pat 5th frame
# finish merging 8-cat_pat 6th frame
# finish merging 8-cat_pat 7th frame
# finish merging 8-cat_pat 8th frame
# finish merging 8-cat_pat 9th frame
# finish merging 8-cat_pat 10th frame
# finish merging 8-cat_pat 11th frame
# finish merging 8-cat_pat 12th frame
# finish merging 8-cat_pat 13th frame
# finish merging 8-cat_pat 14th frame
# finish merging 8-cat_pat 15th frame
# finish merging 8-cat_pat 16th frame
# finish merging 8-cat_pat 17th frame
# finish merging 8-cat_pat 18th frame
# finish merging 8-cat_pat 19th frame
# finish merging 8-cat_pat 20th frame
# finish merging 8-cat_pat 21th frame
# finish merging 8-cat_pat 22th frame
# finish merging 8-cat_pat 23th frame
# finish merging 8-cat_pat 24th frame
# finish merging 8-cat_pat 25th frame
# finish merging 8-cat_pat 26th frame
# finish merging 8-cat_pat 27th frame
# finish merging 8-cat_pat 28th frame
# finish merging 8-cat_pat 29th frame
# finish merging 8-cat_pat 30th frame
# finish merging 8-cat_pat 31th frame
# finish merging 8-cat_pat 32th frame
# finish merging 8-cat_pat 33th frame
# finish merging 8-cat_pat 34th frame
# finish merging 8-cat_pat 35th frame
# finish merging 8-cat_pat 36th frame
# finish merging 8-cat_pat 37th frame
# finish merging 8-cat_pat 38th frame
# finish merging 8-cat_pat 39th frame
# finish merging 8-cat_pat 40th frame
# finish merging 8-cat_pat 41th frame
# finish merging 8-cat_pat 42th frame
# finish merging 8-cat_pat 43th frame
# finish merging 8-cat_pat 44th frame
# finish merging 8-cat_pat 45th frame
# finish merging 8-cat_pat 46th frame
# finish merging 8-cat_pat 47th frame
# finish merging 8-cat_pat 48th frame
# finish merging 8-cat_pat 49th frame
# finish merging 8-cat_pat 50th frame
# finish merging 8-cat_pat 51th frame
# finish merging 8-cat_pat 52th frame
# finish merging 8-cat_pat 53th frame
# finish merging 8-cat_pat 54th frame
# finish merging 8-cat_pat 55th frame
# finish merging 8-cat_pat 56th frame
# finish merging 8-cat_pat 57th frame
# finish merging 8-cat_pat 58th frame
# finish merging 8-cat_pat 59th frame
# finish merging 8-cat_pat 60th frame
# finish merging 8-cat_pat 61th frame
# finish merging 8-cat_pat 62th frame
# finish merging 8-cat_pat 63th frame
# finish merging 8-cat_pat 64th frame
# finish merging 8-cat_pat 65th frame
# finish merging 8-cat_pat 66th frame
# finish merging 8-cat_pat 67th frame
# finish merging 8-cat_pat 68th frame
# finish merging 8-cat_pat 69th frame
# finish merging 8-cat_pat 70th frame
# finish merging 8-cat_pat 71th frame
# finish merging 8-cat_pat 72th frame
# finish merging 8-cat_pat 73th frame
# finish merging 8-cat_pat 74th frame
# finish merging 8-cat_pat 75th frame
# finish merging 8-cat_pat 76th frame
# finish merging 8-cat_pat 77th frame
# finish merging 8-cat_pat 78th frame
# finish merging 8-cat_pat 79th frame
# finish merging 8-cat_pat 80th frame
# finish merging 8-cat_pat 81th frame
# finish merging 8-cat_pat 82th frame
# finish merging 8-cat_pat 83th frame
# finish merging 8-cat_pat 84th frame
# finish merging 8-cat_pat 85th frame
# finish merging 8-cat_pat 86th frame
# finish merging 8-cat_pat 87th frame
# finish merging 8-cat_pat 88th frame
# finish merging 8-cat_pat 89th frame
# finish merging 8-cat_pat 90th frame
# finish merging 8-cat_pat 91th frame
# finish merging 8-cat_pat 92th frame
# finish merging 8-cat_pat 93th frame
# finish merging 8-cat_pat 94th frame
# finish merging 8-cat_pat 95th frame
# finish merging 8-cat_pat 96th frame
# finish merging 8-cat_pat 97th frame
# finish merging 8-cat_pat 98th frame
# finish merging 8-cat_pat 99th frame
# finish merging 8-cat_pat 100th frame
# finish merging 8-cat_pat 101th frame
# finish merging 8-cat_pat 102th frame
# finish merging 8-cat_pat 103th frame
# finish merging 8-cat_pat 104th frame
# finish merging 8-cat_pat 105th frame
# finish merging 8-cat_pat 106th frame
# finish merging 8-cat_pat 107th frame
# finish merging 8-cat_pat 108th frame
# finish merging 8-cat_pat 109th frame
# finish merging 8-cat_pat 110th frame
# finish merging 8-cat_pat 111th frame
# finish merging 8-cat_pat 112th frame
# finish merging 8-cat_pat 113th frame
# finish merging 8-cat_pat 114th frame
# finish merging 8-cat_pat 115th frame
# finish merging 8-cat_pat 116th frame
# finish merging 8-cat_pat 117th frame
# finish merging 8-cat_pat 118th frame
# finish merging 8-cat_pat 119th frame
# finish merging 8-cat_pat 120th frame
# finish merging 8-cat_pat 121th frame
# finish merging 8-cat_pat 122th frame
# finish merging 8-cat_pat 123th frame
# finish merging 8-cat_pat 124th frame
# finish merging 8-cat_pat 125th frame
# finish merging 8-cat_pat 126th frame
# finish merging 8-cat_pat 127th frame
# finish merging 8-cat_pat 128th frame
# finish merging 8-cat_pat 129th frame
# finish merging 8-cat_pat 130th frame
# finish merging 8-cat_pat 131th frame
# finish merging 8-cat_pat 132th frame
# finish merging 8-cat_pat 133th frame
# finish merging 8-cat_pat 134th frame
# finish merging 8-cat_pat 135th frame
# finish merging 8-cat_pat 136th frame
# finish merging 8-cat_pat 137th frame
# finish merging 8-cat_pat 138th frame
# finish merging 8-cat_pat 139th frame
# finish merging 8-cat_pat 140th frame
# finish merging 8-cat_pat 141th frame
# finish merging 8-cat_pat 142th frame
# finish merging 8-cat_pat 143th frame
# finish merging 8-cat_pat 144th frame
# finish merging 8-cat_pat 145th frame
# finish merging 8-cat_pat 146th frame
# finish merging 8-cat_pat 147th frame
# finish merging 8-cat_pat 148th frame
# finish merging 8-cat_pat 149th frame
# finish merging 8-cat_pat 150th frame
# ...
# finish merging 12-mouse_fight 86th frame
# finish merging 12-mouse_fight 87th frame
# finish merging 12-mouse_fight 88th frame
# finish merging 12-mouse_fight 89th frame
# finish merging 12-mouse_fight 90th frame
# finish merging 12-mouse_fight 91th frame
# finish merging 12-mouse_fight 92th frame
# finish merging 12-mouse_fight 93th frame
# finish merging 12-mouse_fight 94th frame
# finish merging 12-mouse_fight 95th frame
# finish merging 12-mouse_fight 96th frame
# finish merging 12-mouse_fight 97th frame
# finish merging 12-mouse_fight 98th frame
# finish merging 12-mouse_fight 99th frame
# finish merging 12-mouse_fight 100th frame
# finish merging 12-mouse_fight 101th frame
# finish merging 12-mouse_fight 102th frame
# finish merging 12-mouse_fight 103th frame
# finish merging 12-mouse_fight 104th frame
# finish merging 12-mouse_fight 105th frame
# finish merging 12-mouse_fight 106th frame
# finish merging 12-mouse_fight 107th frame
# finish merging 12-mouse_fight 108th frame
# finish merging 12-mouse_fight 109th frame
# finish merging 12-mouse_fight 110th frame
# finish merging 12-mouse_fight 111th frame
# finish merging 12-mouse_fight 112th frame
# finish merging 12-mouse_fight 113th frame
# finish merging 12-mouse_fight 114th frame
# finish merging 12-mouse_fight 115th frame
# finish merging 12-mouse_fight 116th frame
# finish merging 12-mouse_fight 117th frame
# finish merging 12-mouse_fight 118th frame
# finish merging 12-mouse_fight 119th frame
# finish merging 12-mouse_fight 120th frame
# finish merging 12-mouse_fight 121th frame
# finish merging 12-mouse_fight 122th frame
# finish merging 12-mouse_fight 123th frame
# finish merging 12-mouse_fight 124th frame
# finish merging 12-mouse_fight 125th frame
# finish merging 12-mouse_fight 126th frame
# finish merging 12-mouse_fight 127th frame
# finish merging 12-mouse_fight 128th frame
# finish merging 12-mouse_fight 129th frame
# finish merging 12-mouse_fight 130th frame
# finish merging 12-mouse_fight 131th frame
# finish merging 12-mouse_fight 132th frame
# finish merging 12-mouse_fight 133th frame
# finish merging 12-mouse_fight 134th frame
# finish merging 12-mouse_fight 135th frame
# finish merging 12-mouse_fight 136th frame
# finish merging 12-mouse_fight 137th frame
# finish merging 12-mouse_fight 138th frame
# finish merging 12-mouse_fight 139th frame
# finish merging 12-mouse_fight 140th frame
# finish merging 12-mouse_fight 141th frame
# finish merging 12-mouse_fight 142th frame
# finish merging 12-mouse_fight 143th frame
# finish merging 12-mouse_fight 144th frame
# finish merging 12-mouse_fight 145th frame
# finish merging 12-mouse_fight 146th frame
# finish merging 12-mouse_fight 147th frame
# finish merging 12-mouse_fight 148th frame
# finish merging 12-mouse_fight 149th frame
# finish merging 12-mouse_fight 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/mouse_fight-rep-reshape.tif
# finish merging 12-mouse_fight
# finish merging 13-mouse_birth 1th frame
# finish merging 13-mouse_birth 2th frame
# finish merging 13-mouse_birth 3th frame
# finish merging 13-mouse_birth 4th frame
# finish merging 13-mouse_birth 5th frame
# finish merging 13-mouse_birth 6th frame
# finish merging 13-mouse_birth 7th frame
# finish merging 13-mouse_birth 8th frame
# finish merging 13-mouse_birth 9th frame
# finish merging 13-mouse_birth 10th frame
# finish merging 13-mouse_birth 11th frame
# finish merging 13-mouse_birth 12th frame
# finish merging 13-mouse_birth 13th frame
# finish merging 13-mouse_birth 14th frame
# finish merging 13-mouse_birth 15th frame
# finish merging 13-mouse_birth 16th frame
# finish merging 13-mouse_birth 17th frame
# finish merging 13-mouse_birth 18th frame
# finish merging 13-mouse_birth 19th frame
# finish merging 13-mouse_birth 20th frame
# finish merging 13-mouse_birth 21th frame
# finish merging 13-mouse_birth 22th frame
# finish merging 13-mouse_birth 23th frame
# finish merging 13-mouse_birth 24th frame
# finish merging 13-mouse_birth 25th frame
# finish merging 13-mouse_birth 26th frame
# finish merging 13-mouse_birth 27th frame
# finish merging 13-mouse_birth 28th frame
# finish merging 13-mouse_birth 29th frame
# finish merging 13-mouse_birth 30th frame
# finish merging 13-mouse_birth 31th frame
# finish merging 13-mouse_birth 32th frame
# finish merging 13-mouse_birth 33th frame
# finish merging 13-mouse_birth 34th frame
# finish merging 13-mouse_birth 35th frame
# finish merging 13-mouse_birth 36th frame
# finish merging 13-mouse_birth 37th frame
# finish merging 13-mouse_birth 38th frame
# finish merging 13-mouse_birth 39th frame
# finish merging 13-mouse_birth 40th frame
# finish merging 13-mouse_birth 41th frame
# finish merging 13-mouse_birth 42th frame
# finish merging 13-mouse_birth 43th frame
# finish merging 13-mouse_birth 44th frame
# finish merging 13-mouse_birth 45th frame
# finish merging 13-mouse_birth 46th frame
# finish merging 13-mouse_birth 47th frame
# finish merging 13-mouse_birth 48th frame
# finish merging 13-mouse_birth 49th frame
# finish merging 13-mouse_birth 50th frame
# finish merging 13-mouse_birth 51th frame
# finish merging 13-mouse_birth 52th frame
# finish merging 13-mouse_birth 53th frame
# finish merging 13-mouse_birth 54th frame
# finish merging 13-mouse_birth 55th frame
# finish merging 13-mouse_birth 56th frame
# finish merging 13-mouse_birth 57th frame
# finish merging 13-mouse_birth 58th frame
# finish merging 13-mouse_birth 59th frame
# finish merging 13-mouse_birth 60th frame
# finish merging 13-mouse_birth 61th frame
# finish merging 13-mouse_birth 62th frame
# finish merging 13-mouse_birth 63th frame
# finish merging 13-mouse_birth 64th frame
# finish merging 13-mouse_birth 65th frame
# finish merging 13-mouse_birth 66th frame
# finish merging 13-mouse_birth 67th frame
# finish merging 13-mouse_birth 68th frame
# finish merging 13-mouse_birth 69th frame
# finish merging 13-mouse_birth 70th frame
# finish merging 13-mouse_birth 71th frame
# finish merging 13-mouse_birth 72th frame
# finish merging 13-mouse_birth 73th frame
# finish merging 13-mouse_birth 74th frame
# finish merging 13-mouse_birth 75th frame
# finish merging 13-mouse_birth 76th frame
# finish merging 13-mouse_birth 77th frame
# finish merging 13-mouse_birth 78th frame
# finish merging 13-mouse_birth 79th frame
# finish merging 13-mouse_birth 80th frame
# finish merging 13-mouse_birth 81th frame
# finish merging 13-mouse_birth 82th frame
# finish merging 13-mouse_birth 83th frame
# finish merging 13-mouse_birth 84th frame
# finish merging 13-mouse_birth 85th frame
# finish merging 13-mouse_birth 86th frame
# finish merging 13-mouse_birth 87th frame
# finish merging 13-mouse_birth 88th frame
# finish merging 13-mouse_birth 89th frame
# finish merging 13-mouse_birth 90th frame
# finish merging 13-mouse_birth 91th frame
# finish merging 13-mouse_birth 92th frame
# finish merging 13-mouse_birth 93th frame
# finish merging 13-mouse_birth 94th frame
# finish merging 13-mouse_birth 95th frame
# finish merging 13-mouse_birth 96th frame
# finish merging 13-mouse_birth 97th frame
# finish merging 13-mouse_birth 98th frame
# finish merging 13-mouse_birth 99th frame
# finish merging 13-mouse_birth 100th frame
# finish merging 13-mouse_birth 101th frame
# finish merging 13-mouse_birth 102th frame
# finish merging 13-mouse_birth 103th frame
# finish merging 13-mouse_birth 104th frame
# finish merging 13-mouse_birth 105th frame
# finish merging 13-mouse_birth 106th frame
# finish merging 13-mouse_birth 107th frame
# finish merging 13-mouse_birth 108th frame
# finish merging 13-mouse_birth 109th frame
# finish merging 13-mouse_birth 110th frame
# finish merging 13-mouse_birth 111th frame
# finish merging 13-mouse_birth 112th frame
# finish merging 13-mouse_birth 113th frame
# finish merging 13-mouse_birth 114th frame
# finish merging 13-mouse_birth 115th frame
# finish merging 13-mouse_birth 116th frame
# finish merging 13-mouse_birth 117th frame
# finish merging 13-mouse_birth 118th frame
# finish merging 13-mouse_birth 119th frame
# finish merging 13-mouse_birth 120th frame
# finish merging 13-mouse_birth 121th frame
# finish merging 13-mouse_birth 122th frame
# finish merging 13-mouse_birth 123th frame
# finish merging 13-mouse_birth 124th frame
# finish merging 13-mouse_birth 125th frame
# finish merging 13-mouse_birth 126th frame
# finish merging 13-mouse_birth 127th frame
# finish merging 13-mouse_birth 128th frame
# finish merging 13-mouse_birth 129th frame
# finish merging 13-mouse_birth 130th frame
# finish merging 13-mouse_birth 131th frame
# finish merging 13-mouse_birth 132th frame
# finish merging 13-mouse_birth 133th frame
# finish merging 13-mouse_birth 134th frame
# finish merging 13-mouse_birth 135th frame
# finish merging 13-mouse_birth 136th frame
# finish merging 13-mouse_birth 137th frame
# finish merging 13-mouse_birth 138th frame
# finish merging 13-mouse_birth 139th frame
# finish merging 13-mouse_birth 140th frame
# finish merging 13-mouse_birth 141th frame
# finish merging 13-mouse_birth 142th frame
# finish merging 13-mouse_birth 143th frame
# finish merging 13-mouse_birth 144th frame
# finish merging 13-mouse_birth 145th frame
# finish merging 13-mouse_birth 146th frame
# finish merging 13-mouse_birth 147th frame
# finish merging 13-mouse_birth 148th frame
# finish merging 13-mouse_birth 149th frame
# finish merging 13-mouse_birth 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/mouse_birth-rep-reshape.tif
# finish merging 13-mouse_birth
# finish merging 14-lawn_and_dog 1th frame
# finish merging 14-lawn_and_dog 2th frame
# finish merging 14-lawn_and_dog 3th frame
# finish merging 14-lawn_and_dog 4th frame
# finish merging 14-lawn_and_dog 5th frame
# finish merging 14-lawn_and_dog 6th frame
# finish merging 14-lawn_and_dog 7th frame
# finish merging 14-lawn_and_dog 8th frame
# finish merging 14-lawn_and_dog 9th frame
# finish merging 14-lawn_and_dog 10th frame
# finish merging 14-lawn_and_dog 11th frame
# finish merging 14-lawn_and_dog 12th frame
# finish merging 14-lawn_and_dog 13th frame
# finish merging 14-lawn_and_dog 14th frame
# finish merging 14-lawn_and_dog 15th frame
# finish merging 14-lawn_and_dog 16th frame
# finish merging 14-lawn_and_dog 17th frame
# finish merging 14-lawn_and_dog 18th frame
# finish merging 14-lawn_and_dog 19th frame
# finish merging 14-lawn_and_dog 20th frame
# finish merging 14-lawn_and_dog 21th frame
# finish merging 14-lawn_and_dog 22th frame
# finish merging 14-lawn_and_dog 23th frame
# finish merging 14-lawn_and_dog 24th frame
# finish merging 14-lawn_and_dog 25th frame
# finish merging 14-lawn_and_dog 26th frame
# finish merging 14-lawn_and_dog 27th frame
# finish merging 14-lawn_and_dog 28th frame
# finish merging 14-lawn_and_dog 29th frame
# finish merging 14-lawn_and_dog 30th frame
# finish merging 14-lawn_and_dog 31th frame
# finish merging 14-lawn_and_dog 32th frame
# finish merging 14-lawn_and_dog 33th frame
# finish merging 14-lawn_and_dog 34th frame
# finish merging 14-lawn_and_dog 35th frame
# finish merging 14-lawn_and_dog 36th frame
# finish merging 14-lawn_and_dog 37th frame
# finish merging 14-lawn_and_dog 38th frame
# finish merging 14-lawn_and_dog 39th frame
# finish merging 14-lawn_and_dog 40th frame
# finish merging 14-lawn_and_dog 41th frame
# finish merging 14-lawn_and_dog 42th frame
# finish merging 14-lawn_and_dog 43th frame
# finish merging 14-lawn_and_dog 44th frame
# finish merging 14-lawn_and_dog 45th frame
# finish merging 14-lawn_and_dog 46th frame
# finish merging 14-lawn_and_dog 47th frame
# finish merging 14-lawn_and_dog 48th frame
# finish merging 14-lawn_and_dog 49th frame
# finish merging 14-lawn_and_dog 50th frame
# finish merging 14-lawn_and_dog 51th frame
# finish merging 14-lawn_and_dog 52th frame
# finish merging 14-lawn_and_dog 53th frame
# finish merging 14-lawn_and_dog 54th frame
# finish merging 14-lawn_and_dog 55th frame
# finish merging 14-lawn_and_dog 56th frame
# finish merging 14-lawn_and_dog 57th frame
# finish merging 14-lawn_and_dog 58th frame
# finish merging 14-lawn_and_dog 59th frame
# finish merging 14-lawn_and_dog 60th frame
# finish merging 14-lawn_and_dog 61th frame
# finish merging 14-lawn_and_dog 62th frame
# finish merging 14-lawn_and_dog 63th frame
# finish merging 14-lawn_and_dog 64th frame
# finish merging 14-lawn_and_dog 65th frame
# finish merging 14-lawn_and_dog 66th frame
# finish merging 14-lawn_and_dog 67th frame
# finish merging 14-lawn_and_dog 68th frame
# finish merging 14-lawn_and_dog 69th frame
# finish merging 14-lawn_and_dog 70th frame
# finish merging 14-lawn_and_dog 71th frame
# finish merging 14-lawn_and_dog 72th frame
# finish merging 14-lawn_and_dog 73th frame
# finish merging 14-lawn_and_dog 74th frame
# finish merging 14-lawn_and_dog 75th frame
# finish merging 14-lawn_and_dog 76th frame
# finish merging 14-lawn_and_dog 77th frame
# finish merging 14-lawn_and_dog 78th frame
# finish merging 14-lawn_and_dog 79th frame
# finish merging 14-lawn_and_dog 80th frame
# finish merging 14-lawn_and_dog 81th frame
# finish merging 14-lawn_and_dog 82th frame
# finish merging 14-lawn_and_dog 83th frame
# finish merging 14-lawn_and_dog 84th frame
# finish merging 14-lawn_and_dog 85th frame
# finish merging 14-lawn_and_dog 86th frame
# finish merging 14-lawn_and_dog 87th frame
# finish merging 14-lawn_and_dog 88th frame
# finish merging 14-lawn_and_dog 89th frame
# finish merging 14-lawn_and_dog 90th frame
# finish merging 14-lawn_and_dog 91th frame
# finish merging 14-lawn_and_dog 92th frame
# finish merging 14-lawn_and_dog 93th frame
# finish merging 14-lawn_and_dog 94th frame
# finish merging 14-lawn_and_dog 95th frame
# finish merging 14-lawn_and_dog 96th frame
# finish merging 14-lawn_and_dog 97th frame
# finish merging 14-lawn_and_dog 98th frame
# finish merging 14-lawn_and_dog 99th frame
# finish merging 14-lawn_and_dog 100th frame
# finish merging 14-lawn_and_dog 101th frame
# finish merging 14-lawn_and_dog 102th frame
# finish merging 14-lawn_and_dog 103th frame
# finish merging 14-lawn_and_dog 104th frame
# finish merging 14-lawn_and_dog 105th frame
# finish merging 14-lawn_and_dog 106th frame
# finish merging 14-lawn_and_dog 107th frame
# finish merging 14-lawn_and_dog 108th frame
# finish merging 14-lawn_and_dog 109th frame
# finish merging 14-lawn_and_dog 110th frame
# finish merging 14-lawn_and_dog 111th frame
# finish merging 14-lawn_and_dog 112th frame
# finish merging 14-lawn_and_dog 113th frame
# finish merging 14-lawn_and_dog 114th frame
# finish merging 14-lawn_and_dog 115th frame
# finish merging 14-lawn_and_dog 116th frame
# finish merging 14-lawn_and_dog 117th frame
# finish merging 14-lawn_and_dog 118th frame
# finish merging 14-lawn_and_dog 119th frame
# finish merging 14-lawn_and_dog 120th frame
# finish merging 14-lawn_and_dog 121th frame
# finish merging 14-lawn_and_dog 122th frame
# finish merging 14-lawn_and_dog 123th frame
# finish merging 14-lawn_and_dog 124th frame
# finish merging 14-lawn_and_dog 125th frame
# finish merging 14-lawn_and_dog 126th frame
# finish merging 14-lawn_and_dog 127th frame
# finish merging 14-lawn_and_dog 128th frame
# finish merging 14-lawn_and_dog 129th frame
# finish merging 14-lawn_and_dog 130th frame
# finish merging 14-lawn_and_dog 131th frame
# finish merging 14-lawn_and_dog 132th frame
# finish merging 14-lawn_and_dog 133th frame
# finish merging 14-lawn_and_dog 134th frame
# finish merging 14-lawn_and_dog 135th frame
# finish merging 14-lawn_and_dog 136th frame
# finish merging 14-lawn_and_dog 137th frame
# finish merging 14-lawn_and_dog 138th frame
# finish merging 14-lawn_and_dog 139th frame
# finish merging 14-lawn_and_dog 140th frame
# finish merging 14-lawn_and_dog 141th frame
# finish merging 14-lawn_and_dog 142th frame
# finish merging 14-lawn_and_dog 143th frame
# finish merging 14-lawn_and_dog 144th frame
# finish merging 14-lawn_and_dog 145th frame
# finish merging 14-lawn_and_dog 146th frame
# finish merging 14-lawn_and_dog 147th frame
# finish merging 14-lawn_and_dog 148th frame
# finish merging 14-lawn_and_dog 149th frame
# finish merging 14-lawn_and_dog 150th frame
# finish merging all frames of /home/lzx/data/WF_VC_liuzhaoxi/24.07.08_Q20/natural-movie/process/20240708-175712-wfield/../20240708-175712-natural-movie/20240708-175712-tif-rep-reshape/lawn_and_dog-rep-reshape.tif
# finish merging 14-lawn_and_dog
# finish all merging

# %%
from pupil_utils import *

path_pupil = pjoin(path_out, experiment + '-pupil')
pupil_video_data = glob(pjoin(path_pupil, '*pupil_detection*.mp4'))[0]
pupil_video = read_video(pupil_video_data)
pupil_video_sort = sorting_NatMov_pupil(np.asarray(pupil_video), trialfile[:, 1], n_movie, n_frame)
pupil_video_sort_nmovie = np.concatenate(np.split(pupil_video_sort, pupil_video_sort.shape[2], axis=2),
                                         axis=0).squeeze()

face_video_data = glob(pjoin(path_pupil, experiment + '-event.avi'))[0]
face_video = read_video(face_video_data)
face_video_sort = sorting_NatMov_pupil(np.asarray(face_video), trialfile[:, 1], n_movie, n_frame)
face_video_height, face_video_width = face_video[0].shape[:2]
face_video_sort_nmovie = np.concatenate(np.split(face_video_sort, face_video_sort.shape[2], axis=2),
                                        axis=0).squeeze()

tif_width = 512
tif_height = 512

# ~~~~~~~~~~ start merging face video & pupil video ~~~~~~~~~~
path_pupil_rep_enhance_merge = pjoin(path_out, experiment + '-rep-enhance-pupil')
os.makedirs(path_pupil_rep_enhance_merge, exist_ok=True)

for imovie in range(n_movie):
    path_rep_enhance_ccf_stim = pjoin(path_out, experiment + '-rep-enhance-ccf-stim')
    WF_videofile = pjoin(path_rep_enhance_ccf_stim, movie_name_list[imovie] + '-rep-enhance-ccf-stim.mp4')
    pupil_mergefile = pjoin(path_pupil_rep_enhance_merge, movie_name_list[imovie] + '-rep-enhance-pupil.mp4')
    text = movie_name_list[imovie] + '-rep-enhance-pupil '
    merge_pupil_face_video(pupil_video_sort_nmovie, face_video_sort_nmovie, WF_videofile, pupil_mergefile, tif_width,
                           tif_height, text=text)

# ~~~~~~~~~~ start merging face video & pupil video ~~~~~~~~~~
path_pupil_rep_merge = pjoin(path_out, experiment + '-rep-pupil')
os.makedirs(path_pupil_rep_merge, exist_ok=True)

for imovie in range(n_movie):
    path_rep_ccf_stim = pjoin(path_out, experiment + '-rep-ccf-stim')
    WF_videofile = cv2.VideoCapture(pjoin(path_rep_ccf_stim, movie_name_list[imovie] + '-rep-ccf-stim.mp4'))
    pupil_mergefile = pjoin(path_pupil_rep_merge, movie_name_list[imovie] + '-rep-pupil.mp4')
    text = movie_name_list[imovie] + '-rep-pupil '
    merge_pupil_face_video(pupil_video_sort_nmovie, face_video_sort_nmovie, WF_videofile, pupil_mergefile, tif_width,
                           tif_height, text=text)

# ~~~~~~~~~~ start merging face video & pupil video ~~~~~~~~~~
path_pupil_merge = pjoin(path_out, experiment + '-avg-pupil')
os.makedirs(path_pupil_merge, exist_ok=True)

for imovie in range(n_movie):
    path_ccf_stim = pjoin(path_out, experiment + '-avg-ccf-stim')
    WF_videofile = cv2.VideoCapture(pjoin(path_ccf_stim, movie_name_list[imovie] + '-ccf-stim.mp4'))
    pupil_mergefile = pjoin(path_pupil_merge, movie_name_list[imovie] + '-avg-pupil.mp4')
    text = movie_name_list[imovie] + '-avg-pupil '
    merge_pupil_face_video(pupil_video_sort_nmovie, face_video_sort_nmovie, WF_videofile, pupil_mergefile, tif_width,
                           tif_height, text=text)

# %%
ccf_regions = allen_transform_regions(None,ccf_regions_reference,
                                      resolution = lmarks['resolution'],
                                        bregma_offset = lmarks['bregma_offset'])
# this loads the atlas in transformed coords
atlas, areanames, brain_mask = atlas_from_landmarks_file(pjoin(path_wfield, 'dorsal_cortex_landmarks.json'))
# this does the transform (warps the original images (the spatial components in the stack))
stack = SVDStack(U,SVTcorr)
stack.set_warped(True, M = lmarks['transform'])

# %%
fig = plt.figure()
# plt.imshow(stack.U_warped[:,:,0], clim=[-0.01,0.01], cmap='coolwarm')
# plt.imshow(stack.originalU[:,:,0], clim=[-0.01,0.01], cmap='coolwarm')
plt.imshow(reconstruct(stack.U_warped,stack.SVT[:,800]), clim=[-0.03,0.03], cmap='gray')
# plot the raw reference because the images were converted
plt.colorbar()
for i,r in ccf_regions.iterrows():
    plt.plot(r['left_x'],r['left_y'],'k',lw=0.3)
    plt.plot(r['right_x'],r['right_y'],'k',lw=0.3)
plt.axis('off')
plt.show()

# %%
pre_lenth = 20
after_lenth = 20
# SVTcorr_sort维度：[nSVD, n_frame, n_movie, n_rep]
SVTcorr_sort = sorting_NatMov(SVTcorr, trialfile[:, 1], n_movie, n_frame, pre_lenth, after_lenth).astype('float32')
print('SVTcorr_sort.shape: (nSVD, n_frame, n_movie, n_rep) ', SVTcorr_sort.shape)
n_rep = SVTcorr_sort.shape[-1]

# %%
n_pc = 3
patch_list = ['V1', 'LM', 'RL', 'AL', 'AM', 'PM', 'P']

patch_pca = np.zeros((n_patch, n_movie, n_pc, n_frame + pre_lenth + after_lenth, n_rep))
patch_pca_var = np.zeros((n_patch, 10))

for i_patch, patch in enumerate(patch_list):
    # 只保留对应脑区像素
    patch_mask = retino['finalPatchesMarked'][patch].array
    patch_tif = np.tensordot(U * patch_mask[:, :, None], SVTcorr_sort, axes=(2, 0)).astype('float16')
    patch_tif = patch_tif[patch_mask != 0]

    # PCA
    patch_tif_2d = patch_tif.reshape(patch_tif.shape[0], -1).T
    pca = PCA(n_components=10)
    pca.fit(patch_tif_2d)
    patch_pc = pca.components_[:n_pc, :]
    patch_pc = np.where(np.mean(patch_pc, axis=1) < 0, -1, 1)[:, None] * patch_pc  # 确保主成分方向为正
    patch_scores = patch_pc @ patch_tif_2d.T
    patch_scores = patch_scores.reshape(n_pc, *patch_tif.shape[1:]).transpose(2, 0, 1, 3)
    # patch_scores = pca.transform(patch_tif_2d)[:,:n_pc].T.reshape(n_pc, *patch_tif.shape[1:]).transpose(2, 0, 1, 3)
    # patch_scores维度[n_movie, n_pc, n_frame, n_rep]
    print('finish PCA of {}'.format(patch))
    patch_pca[i_patch, :, :, :, :] = patch_scores
    patch_pca_var[i_patch, :] = pca.explained_variance_ratio_

np.save(pjoin(path_out, 'patch_pca_scores.npy'), patch_pca)  # 维度(n_patch, n_movie, n_pc, n_frame, n_rep)
patch_pca_var_df = pd.DataFrame(patch_pca_var, index=patch_list,
                                columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10'])
patch_pca_var_df.to_csv(pjoin(path_out, 'patch_pca_var.csv'), index=True)

# %%
# patch_pca = np.load(pjoin(path_out, 'patch_pca_scores.npy'))
#
# # 如果patch需要重新排序
# patch_list_raw = []
# with open(pjoin(path_out, 'patch_list.txt'), 'r') as f:
#     for line in f:
#         patch_list_raw.append(line.strip())
#
# patch_list_reorder = ['V1', 'LM', 'RL', 'AL', 'AM', 'PM', 'A']
# patch_list_index = [patch_list_raw.index(patch) for patch in patch_list_reorder]
# patch_pca_reorder = patch_pca[patch_list_index, :, :, :, :]

# %%
plot_pca(patch_pca, n_patch, n_movie, patch_list, movie_name_list, title=experiment, outpath=path_out,
         pre_lenth=pre_lenth, n_frame=n_frame)

# pca_all = np.concatenate((pca1, pca2, pca3, pca4), axis=-1)
# np.save(pjoin(r'D:\Zhaoxi\mouse_vision\data', 'patch_pca_scores_all.npy'), pca_all)
# plot_pca(pca_all, n_patch, n_movie, patch_list, movie_name_list, title='C92', outpath=r'D:\Zhaoxi\mouse_vision',
#          pre_lenth=pre_lenth, n_frame=n_frame)

# %%
mask = imread(pjoin(path_wfield, 'mask.tif'))
mask = np.where(mask > 0, 1, 0)
# mask = np.rot90(mask, k=3)  # 逆时针旋转90度
u = U * mask[:, :, None]
u = U

# %%
Sigma = np.sqrt(np.sum(SVTcorr ** 2, axis=1))
Sigma = Sigma[:100]
s = np.diag(Sigma)
us = u[:, :, :100] @ s
u_pca = us.reshape(U.shape[0] * U.shape[1], -1)

# %%
'''
a = np.random.randint(0,100,size=(5, 5, 10, 10))
a = a - a.mean()
n_pc = a.shape[0] * a.shape[1]
a_2d = a.reshape(a.shape[0]*a.shape[1], -1).T

# 创建PCA对象
pca = PCA(n_components=n_pc)
# 对a进行主成分分析
pca.fit(a_2d)
# 获取主成分
a_pc = pca.components_.T.reshape(*a.shape[:2], n_pc)
# 获取样本的主成分得分
a_scores = pca.transform(a_2d).T.reshape(n_pc, *a.shape[2:])

a_reconstruct=np.tensordot(a_pc, a_scores, axes=(2, 0))
b = np.random.randint(0,2,size=(a.shape[0], a.shape[1]))

c1 = np.tensordot(a_pc, a_scores, axes=(2, 0)) * b[:, :, None, None]
c1= c1[b != 0]

c2 = np.tensordot(a_pc * b[:, :, None], a_scores, axes=(2, 0))
c2= c2[b != 0]

c1==c2


a.std()-a_reconstruct.std()
Out[233]: 0.07505080233665495
(a-a_reconstruct).std()
Out[234]: 2.0779428930234505
np.sum(a-a_reconstruct)
Out[218]: 1.4210854715202004e-14
a.mean()-a_reconstruct.mean()
Out[237]: -3.2236534429507125e-15
'''

# %%
mean_patch_movie = pd.DataFrame(index=retino['finalPatchesMarked'].keys(), columns=movie_name_list)
mean_patch_movie_rep = pd.DataFrame(index=retino['finalPatchesMarked'].keys(), columns=movie_name_list)

for i in range(n_movie):
    print('start processing {}-{}'.format(i+1, str(movie_list[i])[2:-6]))
    tif_imovie = np.tensordot(U, SVTcorr_sort[:, :, i, :], axes=(2, 0)).astype('float32')
    tif_imovie_frame_mean = np.mean(tif_imovie, axis=2)
    tif_imovie_frame_rep_mean = np.mean(tif_imovie_frame_mean, axis=2)
    for j in retino['finalPatchesMarked'].keys():
        patch_npix = np.count_nonzero(retino['finalPatchesMarked'][j].array)
        npix_total = np.sum(retino['finalPatchesMarked'][j].array * tif_imovie_frame_rep_mean)
        mean_patch_movie.loc[j, movie_name_list[i]] = npix_total / patch_npix
        npix_total_rep = np.asarray(retino['finalPatchesMarked'][j].array.reshape(-1)) @ tif_imovie_frame_mean.reshape(-1, n_rep)
        mean_patch_movie_rep.loc[j, movie_name_list[i]] = npix_total_rep / patch_npix
print('finish mean_patch_movie')

mean_patch_movie.to_csv(pjoin(path_out,'mean_patch_movie.csv'), index=True)
mean_patch_movie_rep.to_csv(pjoin(path_out,'mean_patch_movie_rep.csv'), index=True)

# %%
for col in mean_patch_movie.columns:
    mean_patch_movie[col] = pd.to_numeric(mean_patch_movie[col])
means = mean_patch_movie.to_numpy()

mean_list = np.array(mean_patch_movie_rep.to_numpy().tolist())
n_patch = mean_list.shape[0]
means_rep = mean_list.reshape(n_patch, n_movie, n_rep)

plot_heatmap(means, mean_patch_movie.columns, mean_patch_movie.index, vmin=-0.002, vmax=0.007,
             title='mean of repetition and frames', outfile=pjoin(path_out, 'mean_patch_movie.png'))

# %%
import seaborn as sns

def str_to_matrix(s):
    # 去除首尾的方括号，并将字符串以空格分隔为列表
    values = s.strip('[]').split()
    # 将列表中的字符串转换为 float 类型，并重新组成矩阵
    matrix = np.array([float(val) for val in values], dtype=np.float32)
    return matrix

def read_df_csv(file_path, index_list):
    df = pd.read_csv(file_path, index_col=0)
    df = df.applymap(str_to_matrix)
    df = df.reindex(index_list)
    array = np.array(df.to_numpy().tolist())
    return array

# %%
patch_list = ['V1', 'LM', 'RL', 'AL', 'AM', 'PM', 'A']
patch_movie1 = read_df_csv(r'Y:\WF_VC_liuzhaoxi\24.3.27_C92\natural-movie\process\20240327-183009-natural-movie\mean_patch_movie_rep.csv', patch_list)
patch_movie2 = read_df_csv(r'Y:\WF_VC_liuzhaoxi\24.04.03_C92\natural-movie\process\20240403-161209-natural-movie\mean_patch_movie_rep.csv', patch_list)
patch_movie3 = read_df_csv(r'Y:\WF_VC_liuzhaoxi\24.04.03_C92\natural-movie\process\20240403-172109-natural-movie\mean_patch_movie_rep.csv', patch_list)
patch_movie4 = read_df_csv(r'Y:\WF_VC_liuzhaoxi\24.04.03_C92\natural-movie\process\20240403-192107-natural-movie\mean_patch_movie_rep.csv', patch_list)
patch_movie_all = np.concatenate((patch_movie1,patch_movie2,patch_movie3,patch_movie4), axis=2)
patch_movie_all_mean = np.mean(patch_movie_all, axis=2)
patch_movie_all_mean_df = pd.DataFrame(patch_movie_all_mean, index=patch_list, columns=movie_name_list)
patch_movie_all_mean_df.to_csv('patch_movie_20rep-mean.csv')

# %%
cor_rep = np.array([np.corrcoef(rep) for rep in patch_movie_all.transpose(2, 0, 1)])
cor_mean = np.mean(cor_rep, )
cor_df = pd.DataFrame(cor_mean, index=patch_list, columns=patch_list)
cor_df.to_csv('cor_mean.csv')

# %%
n_max=5
max_indices_mean = np.argsort(-patch_movie_all_mean, axis=1)[:, :n_max]
max_indices = np.argsort(-patch_movie_all, axis=1)[:, :n_max, :]
# 初始化一个空列表来存储每个脑区的交集
intersection_list = []
# 对于每个脑区
for i in range(n_patch):
    # 创建一个集合，包含所有重复的 top3 坐标
    top3_set = set(max_indices[i, :, :].flatten())
    # 对于每个重复
    for j in range(max_indices.shape[2]):
        # 创建一个集合，包含当前重复的 top3 坐标
        rep_set = set(max_indices[i, :, j])
        # 取当前重复的 top3 坐标与之前重复的 top3 坐标集合的交集
        top3_set.intersection_update(rep_set)
    # 将当前脑区的交集添加到列表中
    intersection_list.append(top3_set)
# 打印结果
for i, intersection in enumerate(intersection_list):
    print(f"Brain region {i+1} intersection:", intersection)

# %%
cluster = pd.read_csv('clustered_df.csv', index_col=0)
fig, ax = plt.subplots(figsize=(10, 10))
fig.set_facecolor('white')
sns.boxplot(data=cluster, ax=ax, showfliers=True)
# sns.stripplot(data=patch_movie_all_mean.T, color=".3", size=5, edgecolor="white", linewidth=0.5, ax=ax)
ax.set_ylabel('mean ΔF/F scaled', fontsize=10)
ax.set_xticklabels(cluster.columns, rotation=45, ha='right', fontsize=10)
plt.savefig('cluster boxplot.png')
plt.show()

# 画方差条形图
variance = np.var(cluster, axis=0)
fig, ax = plt.subplots(figsize=(6, 4))
fig.set_facecolor('white')
bars = plt.bar(variance.index, variance.values, color='grey')
ax.set_xticklabels(cluster.columns, rotation=45, ha='right', fontsize=10)
ax.set_ylabel('Variance', fontsize=10)
plt.tight_layout()
plt.savefig('cluster variance.png')
plt.show()

# %%
movie_new_list=['forest',
 'stream',
 'birds_forage',
 'cat',
 'Heron',
 'bugs',
 'cat_pat',
 'owl_peck',
 'crow_peck_mouse',
 'cat_catch_mouse',
 'cat_eat_mouse',
 'mouse_fight',
 'mouse_catch_bug',
 'mouse_eat_bug',
 'mouse_eat',
 'mouse_birth']
patch_new = patch_movie_all_mean_df.reindex(columns=movie_new_list)
new = patch_movie_all_mean_df.to_numpy()
